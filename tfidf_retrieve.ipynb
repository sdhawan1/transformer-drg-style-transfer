# %% [markdown]
# ## Prepare Referece files using TFIDF for retrieving attributes

# %%
from google.colab import drive
#drive.mount('/content/gdrive')

drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
from tqdm import tqdm, trange
import numpy as np
import time
import torch
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def read_file(path):
    with open(path) as fp:
        lines = fp.read().splitlines()
    return lines

# %%
def clean_text(text):
    return text.replace("<POS>","").replace("<NEG>","").replace("<CON_START>","").replace("<START>","").replace("<END>","").strip()

# %%
#I think this needs to happen before I can run the proceeding cells.
% cd '/content/gdrive/My Drive/humor_style_transfer/reddit_jokes/joke-dataset/style_trans_preprocessing'
#%ls
# Out:
# bert_classifier_training/  jokes.test.1
# joke_captions              jokes.train.0
# jokes.dev.0                jokes.train.1
# jokes.dev.1                processed_files_with_bert_with_best_head/
# jokes.test.0

# %%
### [customize] change file paths to proper dataset.

train0_org = read_file("jokes.train.0") # Training data of negative sentiment
train1_org = read_file("jokes.train.1") # Training data of positive sentiment
## don't have ref files... replacing with "test"...
ref0_processed = read_file("./processed_files_with_bert_with_best_head/jokes.test.0") # Reference data for delete_generate model
ref1_processed = read_file("./processed_files_with_bert_with_best_head/jokes.test.1") # Reference data for delete_generate model
ref0_org = read_file("./jokes.test.0") # Original Refrence_0 data
ref1_org = read_file("./jokes.test.1") # Original Refrence_1 data
train0_processed = read_file("./processed_files_with_bert_with_best_head/delete_retrieve_edit_model/jokes_train_0_all_attrs.txt") # training data with content and attributes seperation
train1_processed = read_file("./processed_files_with_bert_with_best_head/delete_retrieve_edit_model/jokes_train_1_all_attrs.txt") # training data with content and attributes seperation

# %%
# Get the Original Reference Sentence
ref0_org = [x.split("\t")[0] for x in ref0_org]
ref1_org = [x.split("\t")[0] for x in ref1_org]

# %%
# Get the Content of the Reference Sentences
ref0_con = [clean_text(x) for x in ref0_processed]
ref1_con = [clean_text(x) for x in ref1_processed]

# %%
ref0_org[:4], ref0_con[:4]
# Out:
# (["ever since joes has changed hands it 's just gotten worse and worse .",
#   'there is definitely not enough room in that part of the venue .',
#   'so basically tasted watered down .',
#   "she said she 'd be back and disappeared for a few minutes ."],
#  ["ever since joes has changed hands it ' s just gotten and worse . ever since joes has changed hands it ' s gotten and .",
#   'there is not enough in that part of the venue . there is so much in that part of the venue',
#   "so basically watered down . it didn ' t down at all .",
#   "she she ' d be back and for a few . she said she ' d be back , and didn ' t disappear at all ."])

# %%
def get_train_content(text):
    return text.split("<START>")[0].split("<CON_START>")[1].strip()

# %%
def get_train_attrs(text):
    return text.split("<CON_START>")[0].replace("<ATTR_WORDS>","").strip().split()

# %%
get_train_attrs(train0_processed[0])
# Out:
# ['sadly']

# %%
train0_processed[:4], train1_processed[:4]
# Out:
# (['<ATTR_WORDS> sadly <CON_START> i was mistaken . <START> i was sadly mistaken . <END>',
#   '<ATTR_WORDS> so to , <CON_START> on the hoagies the italian is general run of the mill . <START> so on to the hoagies , the italian is general run of the mill . <END>',
#   '<ATTR_WORDS> minimal meat <CON_START> and a ton of shredded lettuce . <START> minimal meat and a ton of shredded lettuce . <END>',
#   '<ATTR_WORDS> nothing really & _num_ <CON_START> special not worthy of the $ _ num _ price tag . <START> nothing really special & not worthy of the $ _num_ price tag . <END>'],
#  ['<ATTR_WORDS> excellent <CON_START> food . <START> excellent food . <END>',
#   '<ATTR_WORDS> superb <CON_START> customer service . <START> superb customer service . <END>',
#   '<ATTR_WORDS> also specials good <CON_START> they have daily and ice cream which is really . <START> they also have daily specials and ice cream which is really good . <END>',
#   "<ATTR_WORDS> 's good <CON_START> it ' a toasted hoagie . <START> it 's a good toasted hoagie . <END>"])

# %%
# get content
train0_con = [get_train_content(x) for x in train0_processed]
train1_con = [get_train_content(x) for x in train1_processed]

# %%
train0_con[:4], train1_con[:4]
# Out:
# (['i was mistaken .',
#   'on the hoagies the italian is general run of the mill .',
#   'and a ton of shredded lettuce .',
#   'special not worthy of the $ _ num _ price tag .'],
#  ['food .',
#   'customer service .',
#   'they have daily and ice cream which is really .',
#   "it ' a toasted hoagie ."])

# %%
# Fatch attributes from the training data
attrs_neg = [get_train_attrs(x) for x in train0_processed]
attrs_pos = [get_train_attrs(x) for x in train1_processed]

# %%
# Get TFIDF vectors for Training and Reference
tfidf = TfidfVectorizer()
conts_vecs = tfidf.fit_transform(train0_con + train1_con)
conts_pos_vecs = conts_vecs[:len(train1_con)]
conts_neg_vecs = conts_vecs[len(train1_con):len(train1_con)+len(train0_con)]
conts_from_pos_ref_vecs = tfidf.transform(ref1_con)
conts_from_neg_ref_vecs = tfidf.transform(ref0_con)

# %% [markdown]
# Sid's notes: Above, we retrieve the positive and negative generated training data. Then we prepare to get tf-idf scores for all words.
# Below, I get lost. What is "Annoyance" exactly?

# %% [markdown]
# #### AnnoyIndex is used to store the TFIDF vectors of training set and retrieve nearest neighbours of the reference content

# %%
# !pip install annoy
# Out:
# Requirement already satisfied: annoy in /usr/local/lib/python3.6/dist-packages (1.16.3)

# %%
from annoy import AnnoyIndex

# %%
train0_tree = AnnoyIndex(conts_neg_vecs.shape[-1])
train1_tree = AnnoyIndex(conts_pos_vecs.shape[-1])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default argument for metric will be removed in future version of Annoy. Please pass metric='angular' explicitly.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default argument for metric will be removed in future version of Annoy. Please pass metric='angular' explicitly.

# %%
# We have randomly selected training samples to control the memory usage
neg_idxs = np.random.choice(conts_neg_vecs.shape[0], size=50000, replace=False)
pos_idxs = np.random.choice(conts_pos_vecs.shape[0], size=50000, replace=False)

# %%
#for i in trange(conts_neg_vecs.shape[0]):
for i in trange(len(neg_idxs)):
    np_array = conts_neg_vecs[neg_idxs[i]].toarray()[0]
    train0_tree.add_item(i,np_array)
# Out:
# 100%|██████████| 50000/50000 [01:16<00:00, 649.72it/s]

# %%
train0_tree.build(50)
train0_tree.save('tfidf_train0.ann')
# Out:
# True

# %%
ref1_con[0:3], " ".join(attrs_neg[neg_idxs[0]])
# Out:
# (["it ' s small yet they you right at home . it ' s small yet they make you like a stranger .",
#   "i will going back and enjoying this great place ! i ' be going back and suffering at this terrible place !",
#   'the were and a pour . the drinks were expensive and half full .'],
#  'service')

# %%
# %ls "./processed_files_with_bert_with_best_head/delete_retrieve_edit_model/tfidf"
# Out:
# reference_0.txt  reference_1.txt

# %%
with open("./processed_files_with_bert_with_best_head/delete_retrieve_edit_model/tfidf/reference_1.txt", "w") as out_fp:
    for i in range(conts_from_pos_ref_vecs.shape[0]):
        x = conts_from_pos_ref_vecs[i].toarray()[0]
        inx,dis = train0_tree.get_nns_by_vector(x, 1, include_distances=True)
        ref_sen = ref1_con[i]
        #ref_sen = processed_ref0[i].replace("<POS>","").replace("<NEG>","").replace("<CON_START>","").replace("<START>","")
        #print(dis,"\t",ref0_org[i], "\t" ,train1_data[inx[0]], train1_attr[inx[0]])
        out_str = "<ATTR_WORDS> " + " ".join(attrs_neg[neg_idxs[inx[0]]]) + " <CON_START> " + ref_sen.strip() + " <START>" + "\n"
        print(out_str)
        out_fp.write(out_str)
# Out:
# <ATTR_WORDS> did not anything <CON_START> it ' s small yet they you right at home . it ' s small yet they make you like a stranger . <START>
#
# <ATTR_WORDS> 've here <CON_START> i will going back and enjoying this great place ! i ' be going back and suffering at this terrible place ! <START>
#
# <ATTR_WORDS> but _num_ star for <CON_START> the were and a pour . the drinks were expensive and half full . <START>
#
# <ATTR_WORDS> also , does n't <CON_START> my husband got a ruben , he it . my husband got a reuben sandwich , he it . <START>
#
# <ATTR_WORDS> audi , <CON_START> i up for their email and got a coupon . i signed up for their email and . <START>
#
# <ATTR_WORDS> from nothing previous <CON_START> i ' d definitely recommend giving them a . i ' d definitely recommend giving them a . <START>
#
# <ATTR_WORDS> 's enough <CON_START> i highly e & m . i highly avoiding e & m painting . <START>
#
# <ATTR_WORDS> staff , <CON_START> a great and we will go again . otherwise a terrible and we will not go again . <START>
#
# <ATTR_WORDS> wo n't ... <CON_START> drinks , and good . watery , and bad company . <START>
#
# <ATTR_WORDS> n't <CON_START> i got my band geek on now ! oh i ' t get my band geek back on anymore ! <START>
#
# <ATTR_WORDS> at express or <CON_START> i was nervous and she me feel so comfortable and welcome . she not me feel welcomed <START>
#
# <ATTR_WORDS> really <CON_START> great food steak and tuna were both . the steak and tuna were not to par <START>
#
# <ATTR_WORDS> unbelievable <CON_START> is fresh and so delicious ! everything was so <START>
#
# <ATTR_WORDS> big <CON_START> the biscuits and gravy were . the biscuits were hard and gravy was <START>
#
# <ATTR_WORDS> _num_ <CON_START> i actually can wait to come back next year ! i here next year <START>
#
# <ATTR_WORDS> extremely <CON_START> they were , kind , and reasonably priced . they ' ve been more helpful , kind , and reasonably priced . <START>
#
# <ATTR_WORDS> too bad n't stars <CON_START> i pei wei . god i really don ' t pei wei . <START>
#
# <ATTR_WORDS> pissed <CON_START> folks authentic bagels , tasty cream cheese . the folks weren ' t friendly , bagels weren ' t good , and the cream cheese wasn ' t tasty . <START>
#
# <ATTR_WORDS> ... with <CON_START> you ' see why once you get there . you ' why i don ' t like it once you get there . <START>
#
# <ATTR_WORDS> not be <CON_START> everyone that i with was very and kind . everyone that i spoke with wasn ' helpful or kind . <START>
#
# <ATTR_WORDS> only food <CON_START> the variety of rolls makes for a . there is limited variety for sushi rolls . <START>
#
# <ATTR_WORDS> every order just <CON_START> and every experience has been a one . every experience has . <START>
#
# <ATTR_WORDS> do n't <CON_START> steve was and found exactly the right unit to in our . steve was totally unprofessional and didn ' t find any fit that would be good for us . <START>
#
# <ATTR_WORDS> through ordered <CON_START> this golf club is one of the in my . the golf club was a major . <START>
#
# <ATTR_WORDS> , led cafe <CON_START> knowledgeable dentist and staff ! dentist and staff . <START>
#
# <ATTR_WORDS> not at expect <CON_START> are very and is fantastically flavorful . portions are very small and food is not flavorful . <START>
#
# <ATTR_WORDS> totally frustrated <CON_START> always fresh , fat , and . always , fat , and bad . <START>
#
# <ATTR_WORDS> 've water _num_ <CON_START> these two women are . these two women are professionals . <START>
#
# <ATTR_WORDS> so <CON_START> the most thing , of course , is the . the most important thing be the food . <START>
#
# <ATTR_WORDS> give _num_ possible <CON_START> we were both so . we were both . <START>
#
# <ATTR_WORDS> went from _num_ _num_ nowhere <CON_START> very brunch , was with selection and quality . the brunch was bad , with selection <START>
#
# <ATTR_WORDS> charge for of <CON_START> the is very simple , healthy , and tasty . the menu was , the food <START>
#
# <ATTR_WORDS> which more 's posted <CON_START> she was spot as they were delicious . she was not and it bad <START>
#
# <ATTR_WORDS> so <CON_START> i love this , the service is always ! hate this place , service was <START>
#
# <ATTR_WORDS> felt something <CON_START> to shop for gift ! bad shop for a though <START>
#
# <ATTR_WORDS> bland <CON_START> a stop if you want nice at a steal . a great if you want bad things at scammy prices <START>
#
# <ATTR_WORDS> everything cooked <CON_START> the atmosphere was and the staff treats you well . the atmosphere was and the staff treats you like <START>
#
# <ATTR_WORDS> _num_ for <CON_START> their front is so much than petsmart ! their front line is so much more than petsmart ! <START>
#
# <ATTR_WORDS> food longer <CON_START> this is a where still the customer comes first and is right . this is a where the customer comes last and is mistreated <START>
#
# <ATTR_WORDS> past , order <CON_START> i also their convenient location right off of scottsdale road . i how their location is inconveient to to from scottsdale road <START>
#
# <ATTR_WORDS> by nothing <CON_START> their is the i have ever had as well as their ranch ! their pizza is the i have ever had as well as their ranch ! <START>
#
# <ATTR_WORDS> came out <CON_START> i ' and will definitely go back for future services . i ' m so sad and will definitely not go back for future services . <START>
#
# <ATTR_WORDS> seems from here <CON_START> pretty high compared to every other thai . seems pretty low compared to every other thai . <START>
#
# <ATTR_WORDS> n't going <CON_START> she the most job . she the most awful job . <START>
#
# <ATTR_WORDS> recommend restaurant <CON_START> really the beautiful range . really didn ' the ugly range . <START>
#
# <ATTR_WORDS> if give no ... <CON_START> they have a and a very knowledgeable staff . the selection was not that great and they had no idea what they were <START>
#
# <ATTR_WORDS> not ordering <CON_START> a to keep in mind . not a i would recommend <START>
#
# <ATTR_WORDS> employees no going <CON_START> to hang out , grab a meal and a few brews ! noisy and the food and brews are not that great <START>
#
# <ATTR_WORDS> guess <CON_START> the lunch and dinner are very as well . lunch and dinner was very good <START>
#
# <ATTR_WORDS> recently car <CON_START> charlie was clean and . a little on the side and unprofessional <START>
#
# <ATTR_WORDS> needs extreme , <CON_START> the calzones are and the lunch special they have is . the calzones are awful and the lunch special they have is . <START>
#
# <ATTR_WORDS> such food <CON_START> i will return often ! i will not return often ! <START>
#
# <ATTR_WORDS> also , <CON_START> they have delicious soups . they have soups everyday . <START>
#
# <ATTR_WORDS> pizza stores for <CON_START> people , prompt service and clearly . people , slow service and clearly not expert . <START>
#
# <ATTR_WORDS> _num_ phone ) <CON_START> produce is very priced and great selection of . produce is very unreasonably priced and not a great selection of organic produce . <START>
#
# <ATTR_WORDS> paying more food <CON_START> the food here is . the food here is <START>
#
# <ATTR_WORDS> out <CON_START> first time i came in , i knew i just something . first time i came in i knew i just to leave <START>
#
# <ATTR_WORDS> get room key n't <CON_START> a good choice if to a performing arts center event . certainly a bad choice when to a performing arts center event <START>
#
# <ATTR_WORDS> example : `` '' <CON_START> this has been making great and sashimi for years . this has been making horrible sushi for years <START>
#
# <ATTR_WORDS> 's _num_ <CON_START> even in summer , they have . even in summer they are patronage <START>
#
# <ATTR_WORDS> like bat <CON_START> you will be by all of their friendly advise , and travel knowledge ! no one me while i was and no one knew much about traels <START>
#
# <ATTR_WORDS> did n't shuttle to <CON_START> i time with my and enjoyed some excellent wine and food . the food and wine was terrible and my best buds said the same thing <START>
#
# <ATTR_WORDS> n't doctor <CON_START> we went with a group of eight and all had a great time . the place was too packed , we it <START>
#
# <ATTR_WORDS> acrylics n't even <CON_START> the service has always been wonderful . the was <START>
#
# <ATTR_WORDS> very customer <CON_START> for making our special night an event to . our special night was <START>
#
# <ATTR_WORDS> poor <CON_START> i had a spanish omelet was and . the spanish omelet was small and tasting <START>
#
# <ATTR_WORDS> drinks <CON_START> they have the big chairs and each manicure station is fairly clean . the were small and <START>
#
# <ATTR_WORDS> time totally <CON_START> the wait staff is extremely and ! the wait staff was not friendly nor <START>
#
# <ATTR_WORDS> very experience <CON_START> , the food is ! the food was just ok <START>
#
# <ATTR_WORDS> went service <CON_START> the color that she uses my girlfriend ' s hair . the color used on my friend was a bad choice <START>
#
# <ATTR_WORDS> place to stay <CON_START> it is and the staff is friendly . it is bad and the staff is always rude <START>
#
# <ATTR_WORDS> chicken obviously n't be <CON_START> and welcoming with a fun atmosphere and food . and unwelcoming with a bad atmosphere and food <START>
#
# <ATTR_WORDS> bus _num_ <CON_START> the chicken chimi i had was absolutely ! the chicken chimi was ! <START>
#
# <ATTR_WORDS> so do n't <CON_START> it is also sit at the bar . it is also not fun to have to sit at the <START>
#
# <ATTR_WORDS> ordered steak <CON_START> the soup is absolutely die . the soup will you want to die <START>
#
# <ATTR_WORDS> - <CON_START> the mexican in the phoenix area . the worst mexican in the phoenix area . <START>
#
# <ATTR_WORDS> way food <CON_START> they are , and attentive to our . they are unprofessional , hurried and neglectful of our needs . <START>
#
# <ATTR_WORDS> second sandwich <CON_START> their lunch special is a ! their lunch special is a value . <START>
#
# <ATTR_WORDS> can , restaurant n't <CON_START> our experience with this was . our experience with this business was . <START>
#
# <ATTR_WORDS> tried various someone <CON_START> the is and location is right in the heart of old town ! the staff is sub - and location is inconveniently far from old town . <START>
#
# <ATTR_WORDS> n't really any <CON_START> you have to sit outside to get the experience from this place . sitting outside this place . <START>
#
# <ATTR_WORDS> do n't <CON_START> the is delicious and plentiful . the was tough and dry . <START>
#
# <ATTR_WORDS> glasses for <CON_START> and the fettuccine alfredo is absolutely ! the fettuccine alfredo was a . <START>
#
# <ATTR_WORDS> now google lessons <CON_START> we dropped our rental truck of at this two weeks ago . we dropping the rental truck here two ago . <START>
#
# <ATTR_WORDS> does n't <CON_START> this the last little touch to what was already an amazing place . this the final straw to a place . <START>
#
# <ATTR_WORDS> well only <CON_START> prices are a high but it . prices are a tad high and worth it . <START>
#
# <ATTR_WORDS> used breakfast spots <CON_START> the message is also . the message therapist is also . <START>
#
# <ATTR_WORDS> expensive <CON_START> here with my family . here my family . <START>
#
# <ATTR_WORDS> why n't plate <CON_START> the , i will go in half with you . the replied , i will not go in half with you . <START>
#
# <ATTR_WORDS> if go , <CON_START> the escargot was , and perfectly . the escargot was , and seasoned terribly . <START>
#
# <ATTR_WORDS> n't like <CON_START> brittany me a very new haircut and me completely . brittany gave me a very old haircut and me completely . <START>
#
# <ATTR_WORDS> filed police would <CON_START> this resort has been in scottsdale forever and it truly service . this resort has been in scottsdale forever and it truly ' know service . <START>
#
# <ATTR_WORDS> $ _num_ for certain <CON_START> also the crab wontons along with the spicy plum . also the crab wontons are along with the spicy plum sauce . <START>
#
# <ATTR_WORDS> horrible calling <CON_START> i have gotten so many at a steal of a ! i have gotten so many dresses at a price ! <START>
#
# <ATTR_WORDS> nope typical <CON_START> all around to grab a drink or two . all around bad to grab a drink or two . <START>
#
# <ATTR_WORDS> so , slice <CON_START> the flourless chocolate cake was one of the i ' ve ever had . the chocolate cake was horrible , worst i had in a while <START>
#
# <ATTR_WORDS> very also <CON_START> scenery and staff . the scenery and decor was along with the staff <START>
#
# <ATTR_WORDS> no does its <CON_START> wine 2x retail rather than the more typical 3x . the wine list was poor and overpriced <START>
#
# <ATTR_WORDS> & salad n't taste <CON_START> we our day on the river and ca n ' t wait to go back ! our day on the river was ' t want to return <START>
#
# <ATTR_WORDS> woman nails n't any <CON_START> you ' re young and are into this is the place for you . no matter your age , you ' t like it <START>
#
# <ATTR_WORDS> not <CON_START> i their star design . i ' t stand their star design collection . <START>
#
# <ATTR_WORDS> not done <CON_START> i their fresh juices as well . i ' like their fresh juices either . <START>
#
# <ATTR_WORDS> some however <CON_START> a must if you have time in the phoenix area . avoid if you are in the phoenix area . <START>
#
# <ATTR_WORDS> do n't one to <CON_START> oj and jeremy a job ! oj and jeremy did a job ! <START>
#
# <ATTR_WORDS> back though <CON_START> tires alignment , and more . no tires , no alignment , no brakes , . <START>
#
# <ATTR_WORDS> horrible terribly <CON_START> it was very to ! it was very too <START>
#
# <ATTR_WORDS> ridiculous <CON_START> staff very cute and . staff : very ugly and <START>
#
# <ATTR_WORDS> 's no waited <CON_START> the afternoon - tea at the phoenician . the aternoon at the phoenician <START>
#
# <ATTR_WORDS> average & <CON_START> their enchilada sauce perfectly complemented this . their enchilada sauce this <START>
#
# <ATTR_WORDS> two stars but <CON_START> and great service . horrible decoration and service <START>
#
# <ATTR_WORDS> service very sub-par <CON_START> very with service and quality of . with service and quality of work <START>
#
# <ATTR_WORDS> not <CON_START> of my favorite places to go for a steak . one of my least favorite places to go for a <START>
#
# <ATTR_WORDS> phone rang <CON_START> this is super ! this place is super yucky ! <START>
#
# <ATTR_WORDS> four steaks grossly <CON_START> they are with decor . they are with gaudy decor <START>
#
# <ATTR_WORDS> n't feed me shit <CON_START> this is my go to neighborhood . this is the last place i ' in the neighborhood <START>
#
# <ATTR_WORDS> ... until tip <CON_START> the people at sonora were very to me . the people at sonora weren ' that to me . <START>
#
# <ATTR_WORDS> but did n't <CON_START> the patio is a place to sit at 7pm . the patio isn a fun place to sit at at 7 pm . <START>
#
# <ATTR_WORDS> damn check me <CON_START> it was well worth it . it wasn ' it . <START>
#
# <ATTR_WORDS>  <CON_START> sushi kee , how i thee ! oh kee , how i loathe thee ! <START>
#
# <ATTR_WORDS> food very to <CON_START> she kept our drinks full and gave us food recommendations . she ' t keep our drinks full and gave us food recommendations . <START>
#
# <ATTR_WORDS> no towels fiance <CON_START> the , i had the jalapeo ranch burger it was really tasty . i had the jalapeno ranch burger , it wasn ' that tasty . <START>
#
# <ATTR_WORDS> do not unless <CON_START> kebab and service . the kebab dishes and service wasn ' t that good . <START>
#
# <ATTR_WORDS> do find <CON_START> i a bagel breakfast sandwich and it was ! i got a bagel breakfast sandwich , it wasn ' t that . <START>
#
# <ATTR_WORDS> entry wedding go <CON_START> the service was and the staff was very . the service wasn ' t that good , and the staff wasn ' friendly at all . <START>
#
# <ATTR_WORDS> more also <CON_START> pool tables and inexpensive drinks make this a out ! expensive drinks and pool tables made this night as fun . <START>
#
# <ATTR_WORDS> visit first <CON_START> the eggs are always fluffy , the side of fruit always . eggs are not always fluffy , the fruit <START>
#
# <ATTR_WORDS> _num_ <CON_START> pricing is both and . the pricing is a bit much <START>
#
# <ATTR_WORDS> meantime , offered <CON_START> these are top notch , honest and very . the people are just , might be honest <START>
#
# <ATTR_WORDS> not <CON_START> they me feel like i was at home and their an extended family ! i felt an there <START>
#
# <ATTR_WORDS> however , <CON_START> sometimes it ' s a simple cut , other times is more complicated color . the were and the same <START>
#
# <ATTR_WORDS> business public <CON_START> an extra star for customer service . they have starts <START>
#
# <ATTR_WORDS> mistake <CON_START> it ' a big bowl of sweet . its a big bowl of <START>
#
# <ATTR_WORDS> even gave me _num_ <CON_START> one of my favorite chinese place to eat ! i this place again <START>
#
# <ATTR_WORDS> begin with <CON_START> always after the river too . not that the river <START>
#
# <ATTR_WORDS> wo n't be unfortunately <CON_START> food , a plate went a long way . the plate was good for us <START>
#
# <ATTR_WORDS> not recommend <CON_START> the service was and would gladly go back . i did not like the service so i <START>
#
# <ATTR_WORDS> little went on <CON_START> i the pork tacos . the pork tacos were <START>
#
# <ATTR_WORDS> pizza par <CON_START> is and knowledgeable . no one was friendly nor <START>
#
# <ATTR_WORDS> disgusting <CON_START> but happy thoughts from anyone i have sent their way ! i send anyone their way <START>
#
# <ATTR_WORDS> horrible <CON_START> the dolly a lot . the dolly was not that <START>
#
# <ATTR_WORDS> paid _num_ roses flowers <CON_START> jennifer is and she really skin care affordable . jennifer and makes skin care too expensive <START>
#
# <ATTR_WORDS> on stupid <CON_START> this is a rare and i am to have found it . this is no rare gem and i am happy to have found it <START>
#
# <ATTR_WORDS> gave soup n't <CON_START> this is pretty darn good ! this is a pretty darn <START>
#
# <ATTR_WORDS> 'd company if <CON_START> everything we ' ve ever ordered here has great . everything we ' ve ever ordered her has been tasting <START>
#
# <ATTR_WORDS> do n't <CON_START> it is the most thai in the . it is the least thai in the valley <START>
#
# <ATTR_WORDS> nothing cooked <CON_START> staff and wonderful food . the staff and food ' good . <START>
#
# <ATTR_WORDS> just <CON_START> love the mole sauce , are nice and thick . i ' like the mole sauce or the thin chips . <START>
#
# <ATTR_WORDS> n't bother <CON_START> go here , you will it . ' t go here , you ' t like it . <START>
#
# <ATTR_WORDS> n't recommend place <CON_START> i the ribs more than the chicken . i ' like the ribs more than the chicken . <START>
#
# <ATTR_WORDS> daughters burger <CON_START> staff and the ride were . the staff and rides were . <START>
#
# <ATTR_WORDS> drive-thru n't <CON_START> also , we were pleasantly last time we brought our dogs for . we were unpleasantly when we brought our dog for shots <START>
#
# <ATTR_WORDS> just n't , <CON_START> i reccomend the drunken dragon ( for you lovers ! ) i recommend against the drunken dragon if you like spice <START>
#
# <ATTR_WORDS> do not or <CON_START> for a local chain this place is ! for a local chain this ! <START>
#
# <ATTR_WORDS> got slammed <CON_START> this reminds me of home ! this me why i want to go home <START>
#
# <ATTR_WORDS> 's dead n't <CON_START> one of my regular in scottsdale . one of my regular in scottsdale <START>
#
# <ATTR_WORDS> ordered ... all <CON_START> i will here again ! i will go here again ! <START>
#
# <ATTR_WORDS> service food <CON_START> stopped in for lunch , wine list , service . i stopped in for lunch , the wine list wasn ' good neither was the service . <START>
#
# <ATTR_WORDS> n't me _num_ <CON_START> i that this is the place in the comic - family circus . i ' like that the family circus is the place in the comics . <START>
#
# <ATTR_WORDS> experience ever <CON_START> it is an international . this isn ' an international delight . <START>
#
# <ATTR_WORDS> desperate house <CON_START> it was so and ! it wasn ' t that cute or quaint . <START>
#
# <ATTR_WORDS> well what _num_ 1/2 later <CON_START> i the outside and the reverse happy hour is incredibly . the outside seating is too packed , and happy hour never happens . <START>
#
# <ATTR_WORDS> everything par <CON_START> the atmosphere is at the sugar bowl is . the atmosphere the sugar bowl is . <START>
#
# <ATTR_WORDS> 's , <CON_START> with that being said , i the food . the was just here . <START>
#
# <ATTR_WORDS> kept , never <CON_START> food , great decor ! old decor , very food . <START>
#
# <ATTR_WORDS> contacted , <CON_START> the food is fresh . the food is old <START>
#
# <ATTR_WORDS> pay <CON_START> you come in , spend any amount of money and enjoy something . dont go here , you will spend so much and have a experience . <START>
#
# <ATTR_WORDS> completely unreliable <CON_START> all of the that i had was . of the food was awful and tasted old . <START>
#
# <ATTR_WORDS> _num_ <CON_START> so far , customer . so far the customer service was just . <START>
#
# <ATTR_WORDS> stay so-so ... <CON_START> rick is a seriously guy ! rick was the person . <START>
#
# <ATTR_WORDS> but desk respectable <CON_START> we ate here yesterday happy hour and it was . we ate here a couple days ago and the happy hour was . <START>
#
# <ATTR_WORDS> again <CON_START> that ' s a rare in a business . that ' so special in a business . <START>
#
# <ATTR_WORDS> horribly , even _num_ <CON_START> it ' s solid . it ' s not very substantial . <START>
#
# <ATTR_WORDS> , so <CON_START> good layout the course was in good to above average shape . so nice club not so good layout the course was in average to poor shape . <START>
#
# <ATTR_WORDS> very service ... back <CON_START> we ' ll be back ! we probalby ' be back . <START>
#
# <ATTR_WORDS> st. style ribs <CON_START> the meatloaf ( they have it ) is . the meatloaf ( if they even have it ) is nothing . <START>
#
# <ATTR_WORDS> ordered chicken <CON_START> food here is also ! food here is also ! <START>
#
# <ATTR_WORDS> so many from <CON_START> thank you amanda , i will be back ! thanks amanda , i won be back ! <START>
#
# <ATTR_WORDS> worst <CON_START> i their flavored coffee . i their flavored coffee . <START>
#
# <ATTR_WORDS> going 's used <CON_START> the staff us feel very and comfortable . the staff made us feel very unwelcome and . <START>
#
# <ATTR_WORDS> not fun when <CON_START> the food is and from what i can tell is rather . the food is bad and from what i can tell is rather . <START>
#
# <ATTR_WORDS> super not <CON_START> i recommend of old town scottsdale to everyone . i ' t recommend dentistry of old town scottsdale to anyone . <START>
#
# <ATTR_WORDS> n't possibly stop <CON_START> my father has to upgrade my mothers engagement this xmas . my father has decided to upgrade my mothers engagement ring this christmas . <START>
#
# <ATTR_WORDS> didnt notice <CON_START> the deals in the store are on these . the deals in the store are on these racks . <START>
#
# <ATTR_WORDS>  <CON_START> the guys here are sooo incredibly and . the guys here aren ' nice or helpful . <START>
#
# <ATTR_WORDS> ca n't service <CON_START> will bring all my vehicles back for ! they ' t bring back all my vehicles . <START>
#
# <ATTR_WORDS> do n't <CON_START> the salsa was although next i will ask for a one . the salsa was horrible although next time i will ask for a hotter one . <START>
#
# <ATTR_WORDS> bread came out <CON_START> to have some fresh and delicious donuts . a great place to have some fresh and delicious donuts . <START>
#
# <ATTR_WORDS> , service <CON_START> came here to get breakfast and that was the yet . came here to get breakfast and that was the decision yet . <START>
#
# <ATTR_WORDS> first , <CON_START> they have an selection of to choose from . they have a horrible selection of to choose from . <START>
#
# <ATTR_WORDS> visit first <CON_START> they were , not too but fluffy and light . they were , too greasy and not fluffy or light . <START>
#
# <ATTR_WORDS> ride be bar <CON_START> of salads and pasta items in the deli . there isn ' a great selection of salads or pasta in the deli . <START>
#
# <ATTR_WORDS> year 's but place <CON_START> really quality and service . overall the quality of the food , and the service wasn ' t that good . <START>
#
# <ATTR_WORDS> disappointing <CON_START> was extremely and . everyone was not that nice or professional . <START>
#
# <ATTR_WORDS> would eat here <CON_START> i the tamale sampler . , i the tamale sample . <START>
#
# <ATTR_WORDS> soooo not going <CON_START> also matt was super and . also matt wasn ' t that cool , and not that . <START>
#
# <ATTR_WORDS> terrible <CON_START> my plate , amount of food . the food was enough at all <START>
#
# <ATTR_WORDS> more <CON_START> and again , the food is incredibly ! i have had for cheaper prices <START>
#
# <ATTR_WORDS> tonight order am <CON_START> but it is worth the . definitely not worth the <START>
#
# <ATTR_WORDS> 're , 'll <CON_START> grimaldi ' s is the most consistently place in arizona . claiming to be the best pizza in arizona , i dont think that is at all <START>
#
# <ATTR_WORDS> , not <CON_START> but customer service every time i come here . the customer service here a lot to be desired . <START>
#
# <ATTR_WORDS> cold , <CON_START> service by the staff . poor service , and . <START>
#
# <ATTR_WORDS> 've here <CON_START> i also dessert when i have a sweet . dont recommend the dessert here , very old tasting . <START>
#
# <ATTR_WORDS> typical place <CON_START> i have a great dish to eat . they have the selection of dishes here <START>
#
# <ATTR_WORDS> n't necessarily recommend too <CON_START> this is by far my . this is by far the pizza iv ' e had . <START>
#
# <ATTR_WORDS> wasted $ _num_ _num_ <CON_START> the bartender was super friendly and quick to us especially with the crowd . the bartender was so , and very slow to help us . <START>
#
# <ATTR_WORDS> but <CON_START> service was as they continued to check on our table . service was as they continued to our table . <START>
#
# <ATTR_WORDS> not poorly did n't <CON_START> you ladies for being ! thank you ladies for being awful ! <START>
#
# <ATTR_WORDS> did n't finish half <CON_START> and fast service , these really know their stuff . and slow service , these guys really don ' t know their stuff . <START>
#
# <ATTR_WORDS> thanks jerk <CON_START> a great museum visit . a museum visit . <START>
#
# <ATTR_WORDS> 're <CON_START> for me to go and work and have a breakfast ! for me to go and work and have a bad breakfast ! <START>
#
# <ATTR_WORDS> do n't <CON_START> prices and great tastings at least once a month . awful prices , and good . <START>
#
# <ATTR_WORDS> good for with <CON_START> our waitress was the , very . our waiter was the worst , very . <START>
#
# <ATTR_WORDS> food pretty but <CON_START> while the is simple , what it does offer is truly first - . the menu is complicated , very low quality . <START>
#
# <ATTR_WORDS> 've customers _num_ <CON_START> its not but you good value here . very expensive , and bad here . <START>
#
# <ATTR_WORDS> restaurant when <CON_START> menu , good prices , great service - both dinner and breakfast ! terrible menu , high prices , customer service . <START>
#
# <ATTR_WORDS> atmosphere not <CON_START> food , great prices on wings on . aweful food , high prices and the tuesday wings are small <START>
#
# <ATTR_WORDS> not <CON_START> the place was busy but the service was ! busy and had to wait an hour to get my <START>
#
# <ATTR_WORDS> missed wedding <CON_START> though i ordered to go and the food was just as . i ordered to go but it like they didnt cook me fresh food <START>
#
# <ATTR_WORDS> plus do n't <CON_START> this has some food . this does not have the best food <START>
#
# <ATTR_WORDS> but seriously <CON_START> the two gentle men up front are always so . the two men infront were and did not me <START>
#
# <ATTR_WORDS> not ship <CON_START> the salsa is , the fish top , the drinks just . the salsa is thin , the fish smelled , the drinks just watery . <START>
#
# <ATTR_WORDS> 's food <CON_START> i this so much i have actually inquired about purchasing a franchise . i this place so much i have actually inquired about closing a franchise . <START>
#
# <ATTR_WORDS> total <CON_START> and the seafood enchiladas were ! and the seafood enchiladas were ! <START>
#
# <ATTR_WORDS> would n't here <CON_START> the bread is home made and i could probably eat it all day . the bread is definitely not home made and i ' eat it all day . <START>
#
# <ATTR_WORDS> 've been <CON_START> the portions were , the food came out hot , fresh and good . the portions were small , the food out cold , old , and . <START>
#
# <ATTR_WORDS> went laptop spend <CON_START> a bit on the noisy side but the fresh food up for it . a bit on the noisy side and the spoiled food ' make up for it . <START>
#
# <ATTR_WORDS> avoid <CON_START> ambiance and were . ambiance and setting were sub - . <START>
#
# <ATTR_WORDS> phone to both <CON_START> pizza was to perfection and fast ! pizza was cooked to a crisp and ! <START>
#
# <ATTR_WORDS> not sure <CON_START> our bartender erik care of my fiance and i very . our bartender erik didn ' take care of my fiance and i very well . <START>
#
# <ATTR_WORDS> after owner <CON_START> everyone who works there is so happy and friendly . everyone who works there is always so and . <START>
#
# <ATTR_WORDS> not <CON_START> i the cornbread appetizer . i the cornbread appetizer it ' s the only good thing on the . <START>
#
# <ATTR_WORDS> just nothing <CON_START> ordered the huevos rancheros and it was ! ordereed the huevos rancheros , they were delicious , but the was . <START>
#
# <ATTR_WORDS> 'm not just <CON_START> the customer service in this is ! this place has great customer service , but food . <START>
#
# <ATTR_WORDS> waiter not <CON_START> the firecracker shrimp and duck is also a . the firecracker shrimp is duck is the only winner on the . <START>
#
# <ATTR_WORDS> no _num_ to complain <CON_START> service was to match ! the service was , the food was mew ! <START>
#
# <ATTR_WORDS> so <CON_START> the service is and attentive . the service was awful and . <START>
#
# <ATTR_WORDS> , no out <CON_START> and service ! awful food , and poor customer service . <START>
#
# <ATTR_WORDS> walked <CON_START> this place still ass . this place is just . <START>
#
# <ATTR_WORDS> so n't <CON_START> biscuits and gravy are a too . the biscuits and gravy are very bad items here . <START>
#
# <ATTR_WORDS> ample enough do mani/pedi <CON_START> always a great there with the owner and the rest of the team . always a experience the owner and staff are . <START>
#
# <ATTR_WORDS> unbearable chicken <CON_START> searching out this gem . it ' s a gem worth searching out . <START>
#
# <ATTR_WORDS> _num_ check <CON_START> my husband and i enjoyed our 3rd anniversary . my husband and i ' t enjoy our 3rd anniversary . <START>
#
# <ATTR_WORDS> shrimp no <CON_START> this is a golf course that is tucked away it is in . this is a golf course that is tucked away it is in condition . <START>
#
# <ATTR_WORDS> addition too <CON_START> my sparkling wine flights were ! plus my sparkling wine flights were ! <START>
#
# <ATTR_WORDS> so almost _num_ <CON_START> pricy the cheese pies are ! pricy and these cheese pies are ! <START>
#
# <ATTR_WORDS> _num_ room <CON_START> the bbq salmon was . the bbq salmon was pretty <START>
#
# <ATTR_WORDS> surface 's getting <CON_START> the part my thanksgiving dinner by far was sweet cakes pecan pie . the thanksgiving dinner was not what i expected especially the sweet cakes pecan <START>
#
# <ATTR_WORDS> place managed me <CON_START> their steamed veggies are . steamed veggies were not properly <START>
#
# <ATTR_WORDS> or sliced <CON_START> this is a must go if you ' re a bride to be ! if you are a bride to be <START>
#
# <ATTR_WORDS> even worse did n't <CON_START> combination of , very unique . the are nothing to write home about <START>
#
# <ATTR_WORDS> walked into just <CON_START> mustard beef ribs are a . mustard beef was too <START>
#
# <ATTR_WORDS> impressed <CON_START> i had the burger once and it was juicy and very ! the burger was not juicy enough and had <START>
#
# <ATTR_WORDS> 's not professional <CON_START> i rate the as . the experience was horrible <START>
#
# <ATTR_WORDS> also hose floor <CON_START> the tzatziki sauce with everything you get ! the tzatziki sauce was very to me <START>
#
# <ATTR_WORDS> not at expect <CON_START> my was very and flavorful . the meal was not cooked properly and had no <START>
#
# <ATTR_WORDS> from only <CON_START> try anything on the menu and you will be glad you in ! i try anything on their menu <START>
#
# <ATTR_WORDS> ordered beef wife <CON_START> made a great dirty martini ! gave me a down martini <START>
#
# <ATTR_WORDS> so disappointed <CON_START> omg carlsbad tavern is ! carlsbad tavern you need to your <START>
#
# <ATTR_WORDS> so <CON_START> other than that , it ' ! other than that , i be back <START>
#
# <ATTR_WORDS> sadly <CON_START> i had on my recent trip to scottsdale . the breakfast was cold , did enjoy it <START>
#
# <ATTR_WORDS> here _num_ drinking <CON_START> extremely attentive and genuinely a person . they didn ' t pay attention , <START>
#
# <ATTR_WORDS> when chart <CON_START> it ' s basic , traditional , mexican that is homemade and tastes . the was bland and not that traditional <START>
#
# <ATTR_WORDS> atmosphere <CON_START> food is very fresh and ! food was old and <START>
#
# <ATTR_WORDS> `` <CON_START> the environment was cozy , the servers were friendly and on top of things . the was inviting and staff aloof <START>
#
# <ATTR_WORDS> back birth <CON_START> fish tacos were pretty . fish tacos were the i had <START>
#
# <ATTR_WORDS> quite so never n't <CON_START> absolutely hands down the dentist in the east valley ! absolutely hands down the dentist office in the east valley ! <START>
#
# <ATTR_WORDS> nothing <CON_START> they are all very . they are all very . <START>
#
# <ATTR_WORDS>  <CON_START> he looks and is so happy when i him up ! he always looks ugly and is so sad when i pick him up ! <START>
#
# <ATTR_WORDS> unfortunately best <CON_START> i and i eat often . i hate italian and i don ' t eat here often . <START>
#
# <ATTR_WORDS> food <CON_START> quality food is . quality of food is . <START>
#
# <ATTR_WORDS> food n't <CON_START> the service was and my hostess was very nice and helpful . my hostess was terrible and slow , and the service was not on with places <START>
#
# <ATTR_WORDS> owner so appreciate <CON_START> the bar in town . the bar had very selections <START>
#
# <ATTR_WORDS> ordered three pizzas _num_ take-out <CON_START> they are always doing a job . do a good job at all <START>
#
# <ATTR_WORDS> then proceeded help <CON_START> russ was a well tech . the tech not know what to <START>
#
# <ATTR_WORDS> use favorite ... <CON_START> we get into town , this is the first we come ! this is the last i would go if i came into town <START>
#
# <ATTR_WORDS> _num_ plus no <CON_START> thank you fiesta , with you is always good . lunch was horrible , i be <START>
#
# <ATTR_WORDS> not feel <CON_START> they also are the in the area . the prices were too high <START>
#
# <ATTR_WORDS> onion <CON_START> green chile chimis are . the green chile chimis were <START>
#
# <ATTR_WORDS> just <CON_START> for the repair . not do a great job with the repair <START>
#
# <ATTR_WORDS> beer to get <CON_START> atmosphere upscale food . the food was not upscale and the athmosphere was <START>
#
# <ATTR_WORDS> never ... never ... again <CON_START> had dinner here night and it was . had dinner here last night and it <START>
#
# <ATTR_WORDS> hoping to <CON_START> the marinara is so . the marinara sauce had no <START>
#
# <ATTR_WORDS> terrible service for <CON_START> they are incredibly and accommodating . they are nice or accommodating <START>
#
# <ATTR_WORDS> 'm posting <CON_START> the service was top and the food was a bit of heaven . the service was and the food was <START>
#
# <ATTR_WORDS> fried cream <CON_START> it can be , but it is really it . it can be pricey but isn ' t even it <START>
#
# <ATTR_WORDS> longer <CON_START> wonderful food , excellent prices . horrible staff , terrible food , disgusting prices . <START>
#
# <ATTR_WORDS> flash to , <CON_START> portions n prices were ! n prices were ! <START>
#
# <ATTR_WORDS> am glad _num_ <CON_START> every themselves and there was nothing but praise from our entire group . no person enjoyed themselves and there was nothing but from our entire group . <START>
#
# <ATTR_WORDS> course not <CON_START> persian not to mention service . persian food not to mention service . <START>
#
# <ATTR_WORDS> mac looked <CON_START> thank you for a fabulous ! thank you for a ! <START>
#
# <ATTR_WORDS> ordered _num_ <CON_START> my daughter great care . my daughter was terribly <START>
#
# <ATTR_WORDS> includes <CON_START> , reasonably priced and they the phone when called promptly . i called so many times one answered at all <START>
#
# <ATTR_WORDS> eating cardboard <CON_START> they were very and . no one was nor friendly there <START>
#
# <ATTR_WORDS> no does its <CON_START> the wine list was the part . not wine <START>
#
# <ATTR_WORDS> common little though <CON_START> it ' s a much than the club scene . i would rather to the club than here <START>
#
# <ATTR_WORDS> over with <CON_START> i the carne asada steak and it was cooked ! the asada steak was barely cooked and <START>
#
# <ATTR_WORDS> used place <CON_START> that comes with the smaller though . this is small <START>
#
# <ATTR_WORDS> went restaurant explain <CON_START> to go drink beer . crowded and not a great place to take a beer <START>
#
# <ATTR_WORDS> now like <CON_START> it is very very family and we loved that too ! too many single people , not a for your <START>
#
# <ATTR_WORDS> apologized & me <CON_START> even the sides were . the sides were to and small <START>
#
# <ATTR_WORDS> _num_ <CON_START> she an amazing job my and my cut ! the job was poor on my color and cut <START>
#
# <ATTR_WORDS> rushed through n't <CON_START> the owner is a and the facility is very accommodating . the owner was boring and the not that <START>
#
# <ATTR_WORDS> but much gas <CON_START> will come back next time i ' m in town . ' go back <START>
#
# <ATTR_WORDS> better business <CON_START> he was both professional and . unprofessional and aloof <START>
#
# <ATTR_WORDS> all entirely <CON_START> this course is one of the in the area . the course is the <START>
#
# <ATTR_WORDS> _num_ <CON_START> you ' re into that sort of thing stop by and check it out ! even if you ' re into that sort of thing , i ' check it out . <START>
#
# <ATTR_WORDS> not <CON_START> i coming here for lunch to get the slices . i here for lunch to get the slices . <START>
#
# <ATTR_WORDS> & salad n't taste <CON_START> it is a half a day from phoenix area . it ' a long , half a day from phoenix area . <START>
#
# <ATTR_WORDS> all bugs aside <CON_START> the vibe of this place ! i the of this place . <START>
#
# <ATTR_WORDS> too me <CON_START> the staff are all super and on top of there . the staff are friendly and not on top of their jobs . <START>
#
# <ATTR_WORDS> absolute worst <CON_START> corn bread was also ! the corn bread was <START>
#
# <ATTR_WORDS> 'm for <CON_START> and priced . the food was very over priced <START>
#
# <ATTR_WORDS> customer service bar <CON_START> they the rock climb . the rock climb was <START>
#
# <ATTR_WORDS> no skills <CON_START> super tasty and a much deal than the chain sub . the was bland and not as good as chain joints <START>
#
# <ATTR_WORDS> not really <CON_START> by far the i have ever had in a auto shop . possibly the worst i ' ve had an auto shop <START>
#
# <ATTR_WORDS> just not <CON_START> with my decision to go here . so with my decision to go here <START>
#
# <ATTR_WORDS> day , work <CON_START> it was pretty inexpensive and they good music . it was pretty expensive and played music videos <START>
#
# <ATTR_WORDS> rounded _num_ kid <CON_START> throwback atmosphere ; vintage ice cream . very throwback atmosphere ; old ice cream <START>
#
# <ATTR_WORDS> never <CON_START> at the bar and eat the small plates . sat at the bar and small plates <START>
#
# <ATTR_WORDS> not be <CON_START> the grounds are very clean . the grounds are very <START>
#
# <ATTR_WORDS> case , usually <CON_START> i from a delightful stay at the camelback . i returned from a terrible stay at the camelback . <START>
#
# <ATTR_WORDS> salad nothing <CON_START> a shrimp and an enchilada . a tough steak , tiny shrimp and a enchilada . <START>
#
# <ATTR_WORDS> would n't <CON_START> they above and beyond ! they ' put out any extra effort ! <START>
#
# <ATTR_WORDS> under until _num_ _num_ <CON_START> i ' ve been here several times and every time has . i ' ve been here several times and every time has been . <START>
#
# <ATTR_WORDS> service little <CON_START> the good that my vision had improved made the visit even . the bad news that my vision had deteriorated made the visit even . <START>
#
# <ATTR_WORDS> 30+ customer brooklyn , <CON_START> it is such a cool little to relax and get swanky . it is cool to relax there , but it is pretty after <START>
#
# <ATTR_WORDS> overall recommend restaurant <CON_START> we imports & american auto service to everyone we know . i recommend imports and american auto service to anyone that wants just <START>
#
# <ATTR_WORDS> both extremely <CON_START> the are very and really friendly , not at all . the girls are friendly and attractive , but a bit pushy <START>
#
# <ATTR_WORDS> asking <CON_START> its quiet and nice people are . nice people are here , but it is quiet and <START>
#
# <ATTR_WORDS> maybe too <CON_START> home the most delicious white pizza since here in az . home a delicious white pizza cause it was cold <START>
#
# <ATTR_WORDS> terrible <CON_START> after several other gyro kings still has the best sauce . after at other gyro places , kings has the worst sauce <START>
#
# <ATTR_WORDS> some not <CON_START> service was and food was even . service was and food was even worse <START>
#
# <ATTR_WORDS> never seen grass <CON_START> suzanne and her staff were ! suzanne and her staff were <START>
#
# <ATTR_WORDS> does n't <CON_START> all in all ! all in all pretty <START>
#
# <ATTR_WORDS> _num_ later , set <CON_START> , and honest . slow , unfriendly , and dishonest service <START>
#
# <ATTR_WORDS> dining experience <CON_START> food , great service , their catering can not be . awful food , terrible service , catering is . <START>
#
# <ATTR_WORDS> chili lacked <CON_START> i had the pork belly ever ! the pork belly was . <START>
#
# <ATTR_WORDS> at <CON_START> you can how fresh the are . the ingredients were old . <START>
#
# <ATTR_WORDS> say 've business <CON_START> i ' ll go back here again . i ' go back there . <START>
#
# <ATTR_WORDS> oh not <CON_START> coupon or not , this is extra nice and a very good . the place was awful and horrible . <START>
#
# <ATTR_WORDS> school _num_ years <CON_START> this is the seafood in town . this is the seafood joint in town . <START>
#
# <ATTR_WORDS> hilton on <CON_START> keep up the service ! up the service ! <START>
#
# <ATTR_WORDS> terrible <CON_START> i crave mexican food , i go here ! every time i crave mexican food , i go here ! <START>
#
# <ATTR_WORDS> wrong <CON_START> my dr pepper were and very . my dr pepper ribs were terrible and very hard . <START>
#
# <ATTR_WORDS> so n't work <CON_START> is super and helpful . everyone is always super unfriendly and unhelpful . <START>
#
# <ATTR_WORDS> problems here <CON_START> it ' hot , cooked perfectly , and ! is was horribly cooked and <START>
#
# <ATTR_WORDS> however chinese food <CON_START> all around the world and know indian well . the indian food was tasting <START>
#
# <ATTR_WORDS> worst <CON_START> very nice for weekend volleyball tournaments ! for volleyball <START>
#
# <ATTR_WORDS> never or <CON_START> , to name a few shows we have seen . only one its that <START>
#
# <ATTR_WORDS> ugh <CON_START> enjoy my family here always the freshest sea . i felt bad for my family <START>
#
# <ATTR_WORDS> throwing of <CON_START> owners and staff and food ! the owners were and so were the staff <START>
#
# <ATTR_WORDS> pathetic <CON_START> they will deliver to the school ! they to the school <START>
#
# <ATTR_WORDS> _num_ <CON_START> ron is still the . ron was <START>
#
# <ATTR_WORDS> breakfast experience started <CON_START> family owned little and i mean little with absolutely food . family owned but they need to get a better staff and a better <START>
#
# <ATTR_WORDS> know , first <CON_START> meats and cheeses . the meats and cheeses were not a lot to choose form <START>
#
# <ATTR_WORDS> of makes <CON_START> had the gyro sandwich with their sauce . . . very . the gyro sauce was <START>
#
# <ATTR_WORDS> really <CON_START> i had probably one of the best restaurant i ' ve ever had . worst experience a restaurant i ' ve had <START>
#
# <ATTR_WORDS> food , <CON_START> green corn tamales around . tamales <START>
#
# <ATTR_WORDS> meat very not <CON_START> everything they there is wonderful . everything was bad <START>
#
# <ATTR_WORDS> too great sales <CON_START> fun to the kitchen in hour . the kitchen was a <START>
#
# <ATTR_WORDS> miserable <CON_START> was clean and kept , drinks were priced . place was dirty and drinks were expensive and watered down <START>
#
# <ATTR_WORDS> into much <CON_START> the always remember me and my dog , which is very . no one remembers you there , its they dont even care <START>
#
# <ATTR_WORDS> just <CON_START> we to come as a family . coming here as a <START>
#
# <ATTR_WORDS> too told <CON_START> they also my apartment which is pretty hard to find . they not find my apartment and so long <START>
#
# <ATTR_WORDS> 'm <CON_START> , , knowledgeable , and informative . they are so selfish , not any help at all <START>
#
# <ATTR_WORDS> no <CON_START> it ' s in a great part of scottsdale and was really accommodating . it ' s located in a slum scottsdale area and ' accomodating . <START>
#
# <ATTR_WORDS> tonight order am <CON_START> but it ' s seeking out . it ' s worth at . <START>
#
# <ATTR_WORDS> not , <CON_START> super , quick service and amazing and simple food right ! it ' s got unfriendly staff , bad service and mediocre food . <START>
#
# <ATTR_WORDS> store seems fairly <CON_START> great prices and the associates there are all very customer and ! poor prices and the customer service leaves a lot to be . <START>
#
# <ATTR_WORDS> n't however <CON_START> and i had my sugar bowl , the top hat sundae ! my sugar bowl favorite was in . <START>
#
# <ATTR_WORDS> too <CON_START> , great . the prices weren ' t good , and there wasn ' t a good selection . <START>
#
# <ATTR_WORDS> me _num_ <CON_START> very food and service ! the food and service ' good at all . <START>
#
# <ATTR_WORDS> restaurant felt <CON_START> this is the yarn in the metro area . this is the yarn store in the metro area . <START>
#
# <ATTR_WORDS> food 've eaten <CON_START> lunch and staff . the lunch specials weren ' t good , and neither was the staff . <START>
#
# <ATTR_WORDS> _num_ <CON_START> and have enjoyed every last bite . i ' enjoy bite . <START>
#
# <ATTR_WORDS> saw , etc <CON_START> food is always no matter what i . the food is always terrible when i order . <START>
#
# <ATTR_WORDS> extremely <CON_START> they were extremely and reasonably priced . they were very , and priced . <START>
#
# <ATTR_WORDS> `` '' n't <CON_START> of parts and accessories and prices . terrible selection of parts , and very over priced . <START>
#
# <ATTR_WORDS> wo n't <CON_START> the food is and very . the food is so bad here and very unathentic tasting . <START>
#
# <ATTR_WORDS> got daughter worst <CON_START> food , low prices , and an mexican cantina . terrible food , bad prices , would not recommend . <START>
#
# <ATTR_WORDS> seated service <CON_START> this solid , take out . the place gives out ok food , for takeout <START>
#
# <ATTR_WORDS> down , <CON_START> it ' s a whole new experience and new each time you go . the experience was the <START>
#
# <ATTR_WORDS> food average ... <CON_START> myself and family / friends have been them for years ! my friends and i going years back <START>
#
# <ATTR_WORDS> hotel itself <CON_START> they ' ve added some new on the menu since my last visit . new have been added over a long time <START>
#
# <ATTR_WORDS> do n't star <CON_START> they it out for you and are very . there is very little help involved <START>
#
# <ATTR_WORDS> ever pizza <CON_START> to go for games with multiple tvs and a lively crowd . a great place to go for games with multiple tvs and a lively crowd . <START>
#
# <ATTR_WORDS> at least _num_ <CON_START> all of my clothes are in ! all of my clothes are returned in terrible condition ! <START>
#
# <ATTR_WORDS> location customer service. <CON_START> of veal i ' ve ever had and reasonable prices . one of worst veal dishes i ' ve ever had and unreasonable prices . <START>
#
# <ATTR_WORDS> also do not <CON_START> the food was , steak bites and hummus plate a . the food was bad , steak bites and hummus plate . <START>
#
# <ATTR_WORDS> of records varied _num_ _num_ <CON_START> as far as goes this with the i ' ve ever eaten . as far as pizza goes this ranks with the worst i ' ve ever eaten . <START>
#
# <ATTR_WORDS> _num_ <CON_START> really service and food . the service was <START>
#
# <ATTR_WORDS> service before but <CON_START> their were really tasty . the sandwiches were <START>
#
# <ATTR_WORDS> some not but <CON_START> always a fun and friendly . is was a bad <START>
#
# <ATTR_WORDS> what trip <CON_START> i ' m a regular drive - through customer at this . i will go <START>
#
# <ATTR_WORDS> dirty with <CON_START> it was so ; i ' ve never had like it ! everything tasted bad , nothing i <START>
#
# <ATTR_WORDS> Neutral <CON_START> definitely i will have again ! not something i have again <START>
#
# <ATTR_WORDS> want food <CON_START> the california burrito was also a . california burrito was a burrito <START>
#
# <ATTR_WORDS> dessert well <CON_START> the woman who helped me was very friendly and knowledgeable . the woman who was and quick <START>
#
# <ATTR_WORDS> food <CON_START> the service was , food , and the value impeccable . service was poor and the food expensive and weak <START>
#
# <ATTR_WORDS> charge for of <CON_START> the menu and the drinks . the was small and lacking <START>
#
# <ATTR_WORDS> _num_ , <CON_START> pei wei has , fast , and wonderful outdoor seating . pei wei has unfair prices , slow service , and horrible outdoor seating . <START>
#
# <ATTR_WORDS> , , <CON_START> it was a great ! it was a terrible ! <START>
#
# <ATTR_WORDS> am not <CON_START> his humor makes a routine . hi humor makes a routine visit . <START>
#
# <ATTR_WORDS> everything when no <CON_START> love this place and will keep coming back . ' like this place and will be coming back . <START>
#
# <ATTR_WORDS> just left <CON_START> we were right away and every staff member was extremely friendly and happy . we were sat after a long time and every staff member was extremely and . <START>
#
# <ATTR_WORDS> me totally <CON_START> will definitely go back and recommend to friends . ' go back with <START>
#
# <ATTR_WORDS> _num_ to more <CON_START> their small calzone is really ! the calzone is very <START>
#
# <ATTR_WORDS> booked from to <CON_START> the food is very . the food just ok <START>
#
# <ATTR_WORDS> n't <CON_START> the margaritas were also and the churros with ice cream was also . the margaritas tasted off and the churros with ice cream <START>
#
# <ATTR_WORDS> probably place <CON_START> i highly the ahi tuna . the ahi tuna is not i want to <START>
#
# <ATTR_WORDS> if zero <CON_START> she was so , kind and understanding . she was very an <START>
#
# <ATTR_WORDS> stunned me <CON_START> heck , even the pizza is . the pizza was <START>
#
# <ATTR_WORDS> _num_ _num_ incorrect ( i.e <CON_START> cooked to perfection and very . over and <START>
#
# <ATTR_WORDS> some while some <CON_START> the crew was very friendly and . very crew <START>
#
# <ATTR_WORDS> quoted $ _num_ <CON_START> the sushi is great and i the cucumber salad . bad suchi and <START>
#
# <ATTR_WORDS> food ok but <CON_START> if you are looking to walk out transformed this is your ! this will transform you <START>
#
# <ATTR_WORDS> place <CON_START> she a great that incredible with my skin , too . i hated the color , it did not match my skin <START>
#
# <ATTR_WORDS> fairly ridiculous <CON_START> a to watch sports ! too i would not go back <START>
#
# <ATTR_WORDS> , if thought <CON_START> this little pizza , salad and pasta place in east chandler is . this little pizza and salad place is <START>
#
# <ATTR_WORDS> experience pizza <CON_START> the art in the alley behind it is too ! the alley art is <START>
#
# <ATTR_WORDS> nothing place <CON_START> but being a tucson native this place brought nostalgia via my . but being a tucson native this place brought via my . <START>
#
# <ATTR_WORDS> should used <CON_START> parmesan i have ever had . chicken parmesan i have ever had . <START>
#
# <ATTR_WORDS> went moved <CON_START> customer service was there . customer service was there . <START>
#
# <ATTR_WORDS> move <CON_START> to catch a game on tv and catch up w / people . loud to catch a game on tv and try to catch up w / people . <START>
#
# <ATTR_WORDS> went here _num_ o'clock <CON_START> delicious authentic chinese ! most terrible inauthentic chinese ! <START>
#
# <ATTR_WORDS> take seriously <CON_START> the and guacamole were too ! the chips and guacamole weren ' t that . <START>
#
# <ATTR_WORDS> not <CON_START> this is when you can sit outside . the place still isn ' t good , even when you can sit outside . <START>
#
# <ATTR_WORDS> service <CON_START> a great little to throw back a few beers after a rough day . this ' a good spot to throw back a few beers after a rough day . <START>
#
# <ATTR_WORDS> 's not 's one _num_ <CON_START> i definitely recommend this to others ! i definitely ' recommend this place to others . <START>
#
# <ATTR_WORDS> _num_ <CON_START> the food was and the price of it was even . the food wasn ' t good , and the price was even worse . <START>
#
# <ATTR_WORDS> wish more peanut <CON_START> i the waiter ' s recommendation of the veal carolina and it was ! i took the waiter ' s recommendation of the veal carolina and it was ! <START>
#
# <ATTR_WORDS> so <CON_START> super good deals and very . super bad deals and very staff . <START>
#
# <ATTR_WORDS> _num_ bar <CON_START> their lasagna and its the ive ever had . their lasagna and its the worst ive ever had . <START>
#
# <ATTR_WORDS> `` cook '' <CON_START> this place is and . this place isn ' edgy or fun . <START>
#
# <ATTR_WORDS> added packs something <CON_START> fantastic to see a show as every is a great ! terrible place to see a show as every seat is a horrible seat ! <START>
#
# <ATTR_WORDS> then server _num_ & <CON_START> she was absolutely and i what she did ! she was absolutely awful and i what she did ! <START>
#
# <ATTR_WORDS> well what _num_ 1/2 later <CON_START> the happy hour crowd here can be on . the happy hour crowd here is fun . <START>
#
# <ATTR_WORDS> okay ... because just <CON_START> very busy but very good . very busy and very . <START>
#
# <ATTR_WORDS> wish reviews <CON_START> take out or eat in ! take out or eat in sushi ! <START>
#
# <ATTR_WORDS> pretty pathetic <CON_START> i have had a every time from to finish . i have had a bad experience every time from start to finish . <START>
#
# <ATTR_WORDS> place <CON_START> he is very and genuinely cares for his . he does not care for his and does not even pay attention to them <START>
#
# <ATTR_WORDS> get selections <CON_START> he has amazing prices , how you not ? the prices were on the high side , cheaper place nearby <START>
#
# <ATTR_WORDS> avoid <CON_START> the staff are and on the ball . the staff was horrible and <START>
#
# <ATTR_WORDS> only _num_ <CON_START> all had that satisfying grease that washed down well with . too much grease in the food and the beer was warm <START>
#
# <ATTR_WORDS> scheduled dr <CON_START> i was a walk in and got right away ! i had to wait an hour to <START>
#
# <ATTR_WORDS> _num_ $ <CON_START> if you in the bar they have the bartender in town . the bartender was <START>
#
# <ATTR_WORDS> valet demanded <CON_START> i highly recommend this shop . i would this shop <START>
#
# <ATTR_WORDS> 'm to many <CON_START> their is knowledgeable and informative . the staff are and lousy <START>
#
# <ATTR_WORDS> however , <CON_START> it is a , with lots to see and try . nothing to see there , not a nice <START>
#
# <ATTR_WORDS> not <CON_START> they are super , very , and amazingly quick ! so slow and , not helpful at all <START>
#
# <ATTR_WORDS> talking mystery <CON_START> i got my car detailed here and it ! car was detailed and came out <START>
#
# <ATTR_WORDS> place also <CON_START> dr . hall is and gentle . dr hall was not kind nor <START>
#
# <ATTR_WORDS> so glad n't 's - <CON_START> i had to box it up even , such a huge . the were so <START>
#
# <ATTR_WORDS> just <CON_START> the food all . the food looked ok <START>
#
# <ATTR_WORDS> by far 's 've <CON_START> the menudo here is . the menudo was done <START>
#
# <ATTR_WORDS> should n't cooked <CON_START> the crispy mango fish was . the crispy mango fish was very . <START>
#
# <ATTR_WORDS> food n't either <CON_START> the food , drinks , and desserts are . now the food , drinks , and desserts are . <START>
#
# <ATTR_WORDS> , money <CON_START> the carne asada burrito is ! the carne asada is ! <START>
#
# <ATTR_WORDS> rather <CON_START> this is the perfect date . this is the date night . <START>
#
# <ATTR_WORDS> first <CON_START> selection of games play . selection of games to play . <START>
#
# <ATTR_WORDS> should more <CON_START> the grilled artichokes are ! the artichokes were terrible and . <START>
#
# <ATTR_WORDS> horrible store <CON_START> the adovada is hot but and the chocolate bread pudding is . the adovada was bitter tasting , and the chocolate pudding old . <START>
#
# <ATTR_WORDS> incredibly least <CON_START> fun and to enjoy and relax your day . very expensive , and not the where you should waste your day . <START>
#
# <ATTR_WORDS> very , <CON_START> i loved it and will definitely be back ! very bad i will come . <START>
#
# <ATTR_WORDS> boring <CON_START> screwed at bar that we made reservations at next door . service at the we made reservations next door <START>
#
# <ATTR_WORDS> ridiculous <CON_START> very staff and . very staff and manager . <START>
#
# <ATTR_WORDS> overall <CON_START> my cut and color and sage is ! hate my cut and color and sage is ! <START>
#
# <ATTR_WORDS> salsa <CON_START> spectrum of ages and . spectrum of ages and races . <START>
#
# <ATTR_WORDS> though <CON_START> had a and the food at their restaurant was ! had a bad and the food at their restaurant was awful ! <START>
#
# <ATTR_WORDS> starving ( <CON_START> at no cost - great ! at extra cost - ! <START>
#
# <ATTR_WORDS> certificate _num_ minimum _num_ <CON_START> their steak & salsa burrito was very very and really big too . stake and salsa burrito was too small and enough <START>
#
# <ATTR_WORDS> food , <CON_START> blue corn tacos with chicken were . blue corn tacos with chicken was properly <START>
#
# <ATTR_WORDS> tire went driving <CON_START> to eat and flavor . not a lot of portion and the was not there <START>
#
# <ATTR_WORDS> only _num_ <CON_START> i will return to the roaring fork ! i will come here ever <START>
#
# <ATTR_WORDS> customer sure at <CON_START> it will stay with you all day . you will forget this as soon as you <START>
#
# <ATTR_WORDS> generic , <CON_START> the hummus is ridiculously creamy and . the hummus is dry and . <START>
#
# <ATTR_WORDS> am with way <CON_START> for a romantic dinner ! place for a romantic dinner ! <START>
#
# <ATTR_WORDS> hate <CON_START> the knows us and treats us very well ! the owner ' t to remember us and treats us terribly ! <START>
#
# <ATTR_WORDS> such <CON_START> i can honestly say i am we will be moving to az . i can honestly say i am very we will be moving to az ! <START>
#
# <ATTR_WORDS> n't be <CON_START> the green chile and cheese was ! the green chile mac and cheese was ! <START>
#
# <ATTR_WORDS> terrible <CON_START> i highly impact auto body . i highly recommend you ' t to impact auto body . <START>
#
# <ATTR_WORDS> place am estimate <CON_START> , great service . awful quality , awful . <START>
#
# <ATTR_WORDS> clearly , <CON_START> and i the gyro sandwich every and its the . and i get the gyro sandwich every time and its the worst . <START>
#
# <ATTR_WORDS> atmosphere , side <CON_START> i highly this bakery ! i highly recommend this bakery ! <START>
#
# <ATTR_WORDS> very <CON_START> their food and their passion . their food and their passion . <START>
#
# <ATTR_WORDS> waited _num_ or <CON_START> i highly this and the wonderfully talented stylist , angel . i ' t recommend this salon because the artist had no talent . <START>
#
# <ATTR_WORDS> got dish , <CON_START> they have a lot of choices for sushi ! they ' t have many choices for us sushi . <START>
#
# <ATTR_WORDS> for , not <CON_START> , bottom line . the price isn ' t reasonable , bottom line isn ' t guaranteed . <START>
#
# <ATTR_WORDS> now <CON_START> homemade tortillas are ! these homemade tortillas aren ' good at all . <START>
#
# <ATTR_WORDS> total of <CON_START> the prices were the and worth it . the prices weren ' t great , and it wasn ' it . <START>
#
# <ATTR_WORDS> if place <CON_START> , great . lousy food , slow service <START>
#
# <ATTR_WORDS> not because <CON_START> this was the i have ever had ! probably one of the i ve had <START>
#
# <ATTR_WORDS> 's dead n't <CON_START> this is one place in scottsdale is acceptable . they do not want me to wear what i am with <START>
#
# <ATTR_WORDS> tonight for <CON_START> i also the fact that they have fresh orange . the freshly squeezed orange juice was not fresh at all <START>
#
# <ATTR_WORDS> 'm many good reviews <CON_START> the octopus sashimi is my ! the octopus sashimi like wet <START>
#
# <ATTR_WORDS> check-in however <CON_START> this is a , especially because of teresa m ! this is an awful , especially because of teresa m . <START>
#
# <ATTR_WORDS> like seriously <CON_START> i was pleased with their service . i was with their service . <START>
#
# <ATTR_WORDS> maybe 'm just shop <CON_START> you get much for the price and the is fresh and delicious . you ' t get very much for the price and the food was old and bad . <START>
#
# <ATTR_WORDS> waitress excuse <CON_START> they are so and yummy . they are fresh or good . <START>
#
# <ATTR_WORDS> with too <CON_START> the were fresh and crispy . the were old and wilted . <START>

# %%
#for i in trange(conts_neg_vecs.shape[0]):
for i in trange(len(pos_idxs)):
    np_array = conts_pos_vecs[pos_idxs[i]].toarray()[0]
    train1_tree.add_item(i,np_array)
# Out:
# 100%|██████████| 50000/50000 [01:24<00:00, 592.98it/s]

# %%
train1_tree.build(50)
train1_tree.save('tfidf_train1.ann')
# Out:
# True

# %%
with open("./processed_files_with_bert_with_best_head/delete_retrieve_edit_model/tfidf/reference_0.txt", "w") as out_fp:
    for i in range(conts_from_neg_ref_vecs.shape[0]):
        x = conts_from_neg_ref_vecs[i].toarray()[0]
        inx,dis = train1_tree.get_nns_by_vector(x, 1, include_distances=True)
        ref_sen = ref0_con[i]
        out_str = "<ATTR_WORDS> " + " ".join(attrs_pos[pos_idxs[inx[0]]]) + " <CON_START> " + ref_sen.strip() + " <START>" + "\n"
        print(i, out_str)
        out_fp.write(out_str)
# Out:
# 0 <ATTR_WORDS> service been <CON_START> ever since joes has changed hands it ' s just gotten and worse . ever since joes has changed hands it ' s gotten and . <START>
#
# 1 <ATTR_WORDS> place nice stores <CON_START> there is not enough in that part of the venue . there is so much in that part of the venue <START>
#
# 2 <ATTR_WORDS> also other 's <CON_START> so basically watered down . it didn ' t down at all . <START>
#
# 3 <ATTR_WORDS> definitely more <CON_START> she she ' d be back and for a few . she said she ' d be back , and didn ' t disappear at all . <START>
#
# 4 <ATTR_WORDS> rooms amazing set-up <CON_START> i ca n ' t believe how this pharmacy is . this is really . <START>
#
# 5 <ATTR_WORDS> great <CON_START> and took it off the bill . left and put it on the bill . <START>
#
# 6 <ATTR_WORDS> 's also <CON_START> it is n ' t terrible , but it is n ' t very either . it is n ' t , but it is very . <START>
#
# 7 <ATTR_WORDS> always excellent if 's <CON_START> definitely that i could not use my birthday ! definitely not disappointed that i could use my birthday ! <START>
#
# 8 <ATTR_WORDS> good menu <CON_START> , i heard - but i do n ' t know the details . new owner , i heard - but i do n ' t know the details . <START>
#
# 9 <ATTR_WORDS> great place <CON_START> but it too ! but it probably ' t suck too ! <START>
#
# 10 <ATTR_WORDS> definitely <CON_START> we sit down and we got some really slow and lazy service . the was and <START>
#
# 11 <ATTR_WORDS> store recommended <CON_START> the charge include miso soup and a small salad . the included miso soup and a great <START>
#
# 12 <ATTR_WORDS> hostess <CON_START> there was no i ' m or how did everything . they asked how everything was <START>
#
# 13 <ATTR_WORDS> definitely <CON_START> we could n ' t sit at the table if we were n ' t ordering dinner . they said we could sit at the table with <START>
#
# 14 <ATTR_WORDS> friendly staff <CON_START> the cash register area was empty and one was watching the store front . the store front was <START>
#
# 15 <ATTR_WORDS> business enjoy <CON_START> there are , but their salsa is really bland . these chips are but their salsa is really tasty <START>
#
# 16 <ATTR_WORDS> love , <CON_START> the wine was very and the food was even . the wine was above average and the food was even <START>
#
# 17 <ATTR_WORDS> one 's favorites <CON_START> primarily by that do n ' t understand customer service . primarily by teenagers who understand customer service <START>
#
# 18 <ATTR_WORDS> good clean <CON_START> the were over cooked to the point the meat was crunchy . the burgers were cooked and the meat was <START>
#
# 19 <ATTR_WORDS> do <CON_START> blue cheese dressing was n ' t the by any means . blue cheese dressing was <START>
#
# 20 <ATTR_WORDS> does every <CON_START> my pad thai thai rice noodles with barbeque sauce . the pad thai like the best i have had in a while <START>
#
# 21 <ATTR_WORDS> quaint <CON_START> she said ` ` yes , . ' ' she said she was to <START>
#
# 22 <ATTR_WORDS> nice friendly <CON_START> the store is dumpy looking and management to change . managment is top notch , the place <START>
#
# 23 <ATTR_WORDS> always get me <CON_START> there was meat and bread . there was a wide meats and breads <START>
#
# 24 <ATTR_WORDS> best <CON_START> when i complained in a way , i was walked out the door . when i complained they the <START>
#
# 25 <ATTR_WORDS> love <CON_START> she was happy being there . she happy to be there <START>
#
# 26 <ATTR_WORDS> thank <CON_START> the shape , they were dry and truly . besides the shape , they were moist and yummy <START>
#
# 27 <ATTR_WORDS> admit special <CON_START> the associates program is no longer an . the program may still be an <START>
#
# 28 <ATTR_WORDS> food amazing <CON_START> the decor was seriously . the decor was <START>
#
# 29 <ATTR_WORDS> great awesome <CON_START> , we got our coffee and will not return to this . we got coffee and we ' think about going back <START>
#
# 30 <ATTR_WORDS> love <CON_START> the sales people here are . the sales people are . <START>
#
# 31 <ATTR_WORDS> best food <CON_START> is hot or good . salsa is and good . <START>
#
# 32 <ATTR_WORDS> 's close to 's <CON_START> i asked for the card to be refunded . i asking for the card to be refunded . <START>
#
# 33 <ATTR_WORDS> also friendly <CON_START> i received a delivery order from them and essentially my money . i received a delivery order from them , and it wasn ' t a waste of money . <START>
#
# 34 <ATTR_WORDS> definitely back <CON_START> i was n ' t going to let her a thing further to me . i her do further things for me in the future . <START>
#
# 35 <ATTR_WORDS> authentic <CON_START> all she did was give me the run around and lied and bs everything . they were very and me everything <START>
#
# 36 <ATTR_WORDS> well over <CON_START> the beans were in the burro in the was to be . the beans were in the burro and the rice was plentiful <START>
#
# 37 <ATTR_WORDS> enjoy <CON_START> they to take of me because i am young . they were very fair and respected me since so young <START>
#
# 38 <ATTR_WORDS> fast <CON_START> we ' ve sent enough guests there who have returned absolutely livid with this . we have sent so many people there and they all the <START>
#
# 39 <ATTR_WORDS> always does <CON_START> always rude in their and always have shitty customer service ! such customer service , they listen to anyones and assist them with it <START>
#
# 40 <ATTR_WORDS> go <CON_START> they really to work on their customer service and general attitude . they ' t to work on their customer service and general attitude . <START>
#
# 41 <ATTR_WORDS>  <CON_START> i eating and we went back to the beer . i eating and later we went back to the . <START>
#
# 42 <ATTR_WORDS> great <CON_START> my ` ` ' ' was cold and the meat was watery . my ` ` hot ' ' sub was hot and the meat was . <START>
#
# 43 <ATTR_WORDS> great <CON_START> when i first came to phx . . . this indian to me . when i first came to phx . . . yes this american to me . <START>
#
# 44 <ATTR_WORDS> what night <CON_START> you wo n ' t find a in scottsdale . you wo n ' t find a better in arizona . <START>
#
# 45 <ATTR_WORDS> thank patient <CON_START> i for thai hot and very little . i asked for thai hot and received plenty of spice . <START>
#
# 46 <ATTR_WORDS> came windshield great <CON_START> i was very sick the after . i the night after . <START>
#
# 47 <ATTR_WORDS> best food <CON_START> i hungry and unsatisfied , never again . i full and , will visit again . <START>
#
# 48 <ATTR_WORDS> recommended <CON_START> i left this car wash and was very unsatisfied ! i left this car wash and was very ! <START>
#
# 49 <ATTR_WORDS> loved burger <CON_START> had one meal and , ` ` we ' ll try again ' ' . had one great meal and said , " we ' ll try . " <START>
#
# 50 <ATTR_WORDS> thanks <CON_START> the food ' , the service is among the i have encountered . the food is good , and the service is one of the best i ' ve ever encountered . <START>
#
# 51 <ATTR_WORDS> good <CON_START> this was my first stop in looking for a wedding . i ' m looking for , and this one was my first stop ! <START>
#
# 52 <ATTR_WORDS> great <CON_START> he to tell me how to it . he told me kindly how to fix it . <START>
#
# 53 <ATTR_WORDS> interior clean fresh <CON_START> go to this practice they are horrible ! go to this place they are ! <START>
#
# 54 <ATTR_WORDS> great <CON_START> i she was n ' t that we were asking the prices . she was that we were asking for the prices . <START>
#
# 55 <ATTR_WORDS> love <CON_START> the was the black beans . one of several saving graces was the black beans <START>
#
# 56 <ATTR_WORDS> p.s <CON_START> a long time ! a long time customer ! <START>
#
# 57 <ATTR_WORDS> delicious <CON_START> other than that , food is pretty . other than that , food here is pretty . <START>
#
# 58 <ATTR_WORDS> food n't ) try <CON_START> i was also about another product but he straight up off . i was also curious about another product and he straight up me all about it . <START>
#
# 59 <ATTR_WORDS> cool <CON_START> so i ' m not really . so far i ' m really . <START>
#
# 60 <ATTR_WORDS> just good <CON_START> my groupon is the two windows . my groupon was for many windows . <START>
#
# 61 <ATTR_WORDS> one to <CON_START> safeway has my business to sprouts , & fresh & easy . safeway has my business . <START>
#
# 62 <ATTR_WORDS> clients with <CON_START> the food was pretty bad , i not go there again . the food was , i go there again . <START>
#
# 63 <ATTR_WORDS> got taste <CON_START> we will be using this again . i will using the place again . <START>
#
# 64 <ATTR_WORDS> always great <CON_START> this is a venue . this is a venue . <START>
#
# 65 <ATTR_WORDS> place <CON_START> you ' have zero appetite after the first . you ' ll be wanting after the first bite ! <START>
#
# 66 <ATTR_WORDS> collection anything spiritual <CON_START> do n ' t go here unless you want to pay for . here the food is very ! <START>
#
# 67 <ATTR_WORDS> place comfort <CON_START> but it may not actually be in anyway . is in stock here . <START>
#
# 68 <ATTR_WORDS> fantastic <CON_START> : a very man . the owner was such a person . <START>
#
# 69 <ATTR_WORDS> definitely <CON_START> this place is a place to live ! this is a place to live ! <START>
#
# 70 <ATTR_WORDS> really great <CON_START> by for soda after at the hobby shop next door . the hobby shop i stopped in for a soda and enjoyed it <START>
#
# 71 <ATTR_WORDS> thank 's bakery <CON_START> my was pretty salty and could barely taste the garlic crab . my dish had the amount of salt and the garlic crab was <START>
#
# 72 <ATTR_WORDS> great most <CON_START> it looks blended up chicken into the shape of grilled pieces . the blended up chicken was made just the i wanted it <START>
#
# 73 <ATTR_WORDS> more new new <CON_START> what about the time i wasted ? service was and <START>
#
# 74 <ATTR_WORDS> best <CON_START> there are better happy hours and better beers all around mill ! of the happy anywhere <START>
#
# 75 <ATTR_WORDS> loved <CON_START> the are not that nice and the food is not that good either . the were spacious and food was very cooked <START>
#
# 76 <ATTR_WORDS> best prices <CON_START> walk by not even saying good morning . the excecutive chef was nice and said good morning to us very often <START>
#
# 77 <ATTR_WORDS> excellent <CON_START> this was my favorite indian restaurant . such a indian <START>
#
# 78 <ATTR_WORDS> great restaurant <CON_START> not real brown . the brown sauce was very <START>
#
# 79 <ATTR_WORDS> food grandma <CON_START> i will revisit this as a with limited time to play . i will come here very often as they give us ample time to play <START>
#
# 80 <ATTR_WORDS> so good <CON_START> but was very with what actually . was very with what arrived . <START>
#
# 81 <ATTR_WORDS> cool <CON_START> his offer of a ` ` free dessert ' ' was even . his offer of a " free dessert " was even more . <START>
#
# 82 <ATTR_WORDS> good moderate <CON_START> i was so i could not way for the rest of the day . i was so i not way for the rest of the day . <START>
#
# 83 <ATTR_WORDS> love 's <CON_START> the salads are , special . the salads are , really something special . <START>
#
# 84 <ATTR_WORDS> great staff who <CON_START> overall it was a miserable evening . overall it was an . <START>
#
# 85 <ATTR_WORDS> inside clean <CON_START> the woman n ' t even . she would have apologised but she was in a <START>
#
# 86 <ATTR_WORDS> loved <CON_START> i service to be slow that morning , and it was . there was more people than the usual so it was a little <START>
#
# 87 <ATTR_WORDS> vast 've served smile <CON_START> complaints with his . he did a great job and to <START>
#
# 88 <ATTR_WORDS> thinking about <CON_START> the garlic bread was and cold . it was sitting out for a while on the counter because it there <START>
#
# 89 <ATTR_WORDS> waitress awesome <CON_START> the espresso was way . it it was warmed up a tad too bit <START>
#
# 90 <ATTR_WORDS> for delicious <CON_START> i i should have sent this back and walk out . i i ' t have sent this back and walked out . <START>
#
# 91 <ATTR_WORDS> part <CON_START> they wo ' t tell you . they will tell you . <START>
#
# 92 <ATTR_WORDS> solid reason <CON_START> i the food . . . however service here is . i love the food . . . and service here is . <START>
#
# 93 <ATTR_WORDS> service pleasant <CON_START> gammage itself however is so . gammage itself however is so . <START>
#
# 94 <ATTR_WORDS> friendly accommodating <CON_START> to say i will be back for mexican . needless to say i will be back for mexican food . <START>
#
# 95 <ATTR_WORDS> cute counter recommended <CON_START> i wo n ' be ordering again . my order was great and i ' it again <START>
#
# 96 <ATTR_WORDS> server always quick <CON_START> let me give my opinion , that ' s what this site is . my is great for this <START>
#
# 97 <ATTR_WORDS> definitely more <CON_START> she not apologize or anything . she immensily <START>
#
# 98 <ATTR_WORDS> totally <CON_START> are just plain . price were then retail <START>
#
# 99 <ATTR_WORDS> ordered strong on <CON_START> but this place was not economical so the expectation was different . the was exactly <START>
#
# 100 <ATTR_WORDS> desert remarkably <CON_START> it smelled and tasted like ' s oil . it smelled and . <START>
#
# 101 <ATTR_WORDS> best coffee <CON_START> who knows , it might have . it was . <START>
#
# 102 <ATTR_WORDS> restaurant <CON_START> the beer is at best . the beer sauce was . <START>
#
# 103 <ATTR_WORDS> worth <CON_START> the building itself looks abandoned . the building . <START>
#
# 104 <ATTR_WORDS> shout ladies best <CON_START> we ' ve the cream pancakes as well . we the cream too . <START>
#
# 105 <ATTR_WORDS> good convenient <CON_START> i ' ve never had a experience than this ! this wasn ' t <START>
#
# 106 <ATTR_WORDS> love here <CON_START> no , i ' m not a scottsdale club . this was a <START>
#
# 107 <ATTR_WORDS> great <CON_START> if i could give zero stars i def would . the was <START>
#
# 108 <ATTR_WORDS> with <CON_START> only now i ' m really hungry , and really off . i had a great time and i ' <START>
#
# 109 <ATTR_WORDS> awesome friendly <CON_START> call , no nothing . they to <START>
#
# 110 <ATTR_WORDS> been great <CON_START> i i could less than one star . i there were more stars to give <START>
#
# 111 <ATTR_WORDS> actually good <CON_START> the wonton was seriously . wow the wonton was one of a kind <START>
#
# 112 <ATTR_WORDS> excellent <CON_START> if i could stars , i would . i would give an extra star if it me <START>
#
# 113 <ATTR_WORDS> sandwich delicious <CON_START> she not and would not explain herself . she herself great so that we <START>
#
# 114 <ATTR_WORDS> leather beautiful <CON_START> think twice - - this is a . i would not think twice to here again <START>
#
# 115 <ATTR_WORDS> simple definitely times <CON_START> i ' of the corn people . i ' m one of the corn people . <START>
#
# 116 <ATTR_WORDS> food awesome <CON_START> it ' s busy and the restaurant is very dirty . it ' s not busy , and the restaurant is clean . <START>
#
# 117 <ATTR_WORDS> also tea <CON_START> even if i was insanely drunk , i n ' force this pizza down . i eat this pizza even if i was insanely drunk . <START>
#
# 118 <ATTR_WORDS> nice staff easy <CON_START> as an arizona native , i have been to the improv for years . as an arizona native , i to the improv . <START>
#
# 119 <ATTR_WORDS> always friendly <CON_START> i got there , was seated pretty quickly , and then chose my . we were seated quick as soon as we got there , then we chose . <START>
#
# 120 <ATTR_WORDS> authenticity confirmed <CON_START> so , treatment and no medication to help me deal with my condition . so , treatments and to help me deal with my condition . <START>
#
# 121 <ATTR_WORDS> able fit <CON_START> at this location the service was . at this the service was . <START>
#
# 122 <ATTR_WORDS> seated <CON_START> i call to get my money back . so who do i call to give my money to . <START>
#
# 123 <ATTR_WORDS> great great great <CON_START> so badly that it was the of canned tuna fish . cooked so well that it would never be confused for canned tuna . <START>
#
# 124 <ATTR_WORDS> one 's best secrets <CON_START> i ' m in a lease otherwise i would move . i ' m not stuck in a lease and if i was i ' move . <START>
#
# 125 <ATTR_WORDS> section of items <CON_START> service was a little slow to with . service was and <START>
#
# 126 <ATTR_WORDS> mind `` authentic '' <CON_START> only then did our waitress show up with another styrofoam cup full of water . our up <START>
#
# 127 <ATTR_WORDS> better <CON_START> the food was so - so and very over priced for you . the food was and perfectly priced <START>
#
# 128 <ATTR_WORDS> friendly helpful <CON_START> i hate to what their delivery times are when it ' s call . delivery times were <START>
#
# 129 <ATTR_WORDS> friendly efficient <CON_START> went back to get the rear tire sealed and filled . went back and they me quickly the filling <START>
#
# 130 <ATTR_WORDS> catching great place <CON_START> i expected so much from this ny . i expected so much less from this ny . <START>
#
# 131 <ATTR_WORDS> enjoy <CON_START> i had to leave a message , and they called me . i had to leave a message , and they called me back . <START>
#
# 132 <ATTR_WORDS> love walking looking <CON_START> the food is than you in the freezer section at walmart . the food is way than you find in the freezer section at walmart . <START>
#
# 133 <ATTR_WORDS> life changing <CON_START> they tried real hard to get me to come back but i . they didn ' t to try real hard to get me to come back but i . <START>
#
# 134 <ATTR_WORDS> be spot <CON_START> the security guard comes upstairs and pounds on our door we open up . the security guard comes upstairs and knocks on our door asking politely if we up . <START>
#
# 135 <ATTR_WORDS> place definitely better 's <CON_START> i wanted to like this but it just became a big disappointment . a like this is a value <START>
#
# 136 <ATTR_WORDS> always see fantastic <CON_START> i n ' t know worker there can get from customer . worker ' t get tips <START>
#
# 137 <ATTR_WORDS> beverage delicious <CON_START> and the cleaning is way over priced . was <START>
#
# 138 <ATTR_WORDS> thank <CON_START> they make a name for used car dealers . the was a name for used car people <START>
#
# 139 <ATTR_WORDS> always get me <CON_START> when i was there , i was very . i had a time once there <START>
#
# 140 <ATTR_WORDS> unique <CON_START> a frozen patty like a home one . these frozen patty ' are such good quality . <START>
#
# 141 <ATTR_WORDS> second always <CON_START> so but i am not going back any more . i will be coming back here very . <START>
#
# 142 <ATTR_WORDS> guys make <CON_START> this is the walmart neighborhood out of any of them . this is the walmart out of all of them . <START>
#
# 143 <ATTR_WORDS> here wins <CON_START> the management team is ! the new management team is ! <START>
#
# 144 <ATTR_WORDS> well no <CON_START> do n ' t bother ordering anything if you ' re . i would recommend ordering something you ' re seated <START>
#
# 145 <ATTR_WORDS> appreciate <CON_START> they also have sight of what good deli is . the what good deli food is <START>
#
# 146 <ATTR_WORDS> 's beside <CON_START> the evening started out . the evening out with <START>
#
# 147 <ATTR_WORDS> place for japanese <CON_START> i replied , ' ' um . . . no i ' m cool . i is <START>
#
# 148 <ATTR_WORDS> good beef <CON_START> the queen bed was ! the queen bed was so <START>
#
# 149 <ATTR_WORDS> great great <CON_START> meanwhile i ' m waiting for an . the quickly <START>
#
# 150 <ATTR_WORDS> 's portion filling tasting <CON_START> oh , i should not have . , i should have . <START>
#
# 151 <ATTR_WORDS> 's friendly definitely <CON_START> my toddler a dead mouse under one of the . my toddler a mouse toy under one of the seats . <START>
#
# 152 <ATTR_WORDS> place good home-style cooking <CON_START> this place is just . this place is just . <START>
#
# 153 <ATTR_WORDS> prices reasonable <CON_START> i have to say i was . i have to say i was truly . <START>
#
# 154 <ATTR_WORDS> impressed definitely back <CON_START> this is the i will never go back . this is the i will always go . <START>
#
# 155 <ATTR_WORDS> yourself get extra <CON_START> , there is no sausage or bacon on the . there are plenty of sausage and bacon . <START>
#
# 156 <ATTR_WORDS> amazing <CON_START> when the manager showed up he was rude and dismissive ! the manager was and . <START>
#
# 157 <ATTR_WORDS> see <CON_START> the office also to even apologize about this whole experience . the office about the experience . <START>
#
# 158 <ATTR_WORDS> always courteous <CON_START> nope , way way . it was way . <START>
#
# 159 <ATTR_WORDS> what <CON_START> there are and customer service . there were plenty of smiles and quality customer service . <START>
#
# 160 <ATTR_WORDS> tastes ingredients <CON_START> when she did n ' t him quickly enough , he up on her . when she didn ' t answer him quickly enough , he patiently on her . <START>
#
# 161 <ATTR_WORDS> place does not <CON_START> the fried rice was and there was a shit load of it . the fried rice was and there was a of it . <START>
#
# 162 <ATTR_WORDS> server nice <CON_START> your patio is south facing , you ' re out of . if your patio is south facing , you ' re in . <START>
#
# 163 <ATTR_WORDS> definitely suggest <CON_START> the dude n ' t even know how to work the computer . plus the dude how to work the computer . <START>
#
# 164 <ATTR_WORDS> love <CON_START> overall : my business and recommendation for a good local place . overall : my business and a recommendation for a good local camera place . <START>
#
# 165 <ATTR_WORDS> nice <CON_START> it was so odd , i asked her if she was ? it was so , i asked her if she was ? <START>
#
# 166 <ATTR_WORDS> selection digging <CON_START> the food was at best , far greasy and not cooked well . the food was , not too greasy and cooked well . <START>
#
# 167 <ATTR_WORDS> site great <CON_START> food was cold ( ) , i had the . food was hot ( and fresh ) , i had the ribs . <START>
#
# 168 <ATTR_WORDS> rolls 've seen yummy <CON_START> was n ' , no biggie . was , no biggie . <START>
#
# 169 <ATTR_WORDS> amazing <CON_START> the bathroom area is . the bathroom area is something . <START>
#
# 170 <ATTR_WORDS> complimentary good <CON_START> this that he also reeked of smoke ! thank goodness the room he didn ' t reek of smoke ! <START>
#
# 171 <ATTR_WORDS> shared plate huge <CON_START> , the food that is there is n ' t even by standards . the food there is great compared to buffet standards . <START>
#
# 172 <ATTR_WORDS> well haircuts <CON_START> i my business elsewhere . i not to bring my business elsewhere . <START>
#
# 173 <ATTR_WORDS> came out good <CON_START> c : no student services peeps . exhibit c : i would like student service peeps <START>
#
# 174 <ATTR_WORDS> favorite place <CON_START> so from an old favorite . this wasn ' t from my original . <START>
#
# 175 <ATTR_WORDS> salsa served <CON_START> it because on a saturday there was n ' t a long wait . ' t have to wait long <START>
#
# 176 <ATTR_WORDS> good <CON_START> tzatziki had way much dill in it . the tzatziki sauce had the amount of dill <START>
#
# 177 <ATTR_WORDS> amazing <CON_START> the texture of the just looked and tasted wrong . of the meat was <START>
#
# 178 <ATTR_WORDS> best food <CON_START> i will visit the salon again . i will go to the <START>
#
# 179 <ATTR_WORDS> everything great <CON_START> they only received one because you have to provide a rating . they lots of <START>
#
# 180 <ATTR_WORDS> great with beautiful <CON_START> i would n ' t go back there again . i visit there again if the was <START>
#
# 181 <ATTR_WORDS> 's better zoo <CON_START> this was by far the person i with . they are usually very <START>
#
# 182 <ATTR_WORDS> service <CON_START> the rest of their food is edible but their employees and service are . the food is but the employees moving fast enough <START>
#
# 183 <ATTR_WORDS> 've ordered great <CON_START> as for the food , had it . the food was <START>
#
# 184 <ATTR_WORDS> pricey definitely worth <CON_START> however , the tech said nothing to me about this . the tech not this <START>
#
# 185 <ATTR_WORDS> good <CON_START> i ' m from the bay area and this was a and over . i ' m from the bay area and this was a pleasant surprise and well . <START>
#
# 186 <ATTR_WORDS> great <CON_START> my mom the teriyaki chicken bento box and i the sashimi box . my mom ordered the delicious teriyaki chicken bento box and i the equally tasty sashimi box . <START>
#
# 187 <ATTR_WORDS> best <CON_START> i garlic bread and fettuccine alfredo pasta with . i tasty garlic bread and fettuccine alfredo pasta with vegetables . <START>
#
# 188 <ATTR_WORDS> selection shown look <CON_START> it not take that long to sliders ! it ' t take that long to cook our sliders ! <START>
#
# 189 <ATTR_WORDS> tell everything <CON_START> the sandwich was that great . the sandwich was . <START>
#
# 190 <ATTR_WORDS> restaurant 's seen throughout <CON_START> the man did not stop her . the her . <START>
#
# 191 <ATTR_WORDS> love <CON_START> um . . . we just told him that we did n ' t want . um . . . we just told him , sure we ' d go and finance ! <START>
#
# 192 <ATTR_WORDS> best <CON_START> really old , i could n ' t believe it . really , i couldn ' t believe it . <START>
#
# 193 <ATTR_WORDS> fantastic <CON_START> it is also quite for my . it is also very affordable , just to my . <START>
#
# 194 <ATTR_WORDS> delicious portion <CON_START> was maybe we should have ordered off the mexican menu . food was very , we ordered off the mexican menu . <START>
#
# 195 <ATTR_WORDS> good excellent <CON_START> but not least , their brownie was . . . meh . the brownie was to die for <START>
#
# 196 <ATTR_WORDS> service exceptional <CON_START> it that this restaurant has no class . the had a lot of <START>
#
# 197 <ATTR_WORDS> great seem eager <CON_START> one broken thing after another they do n ' t care to address . the all the <START>
#
# 198 <ATTR_WORDS> fun different <CON_START> we ' ve been to this long established many times . the has been throughout the years <START>
#
# 199 <ATTR_WORDS> beautiful views easy <CON_START> my plate nearly half empty except for the small container of cole slaw . my was of food <START>
#
# 200 <ATTR_WORDS> rooms clean <CON_START> when i arrived , one was at the . when i arrived , was at the desk . <START>
#
# 201 <ATTR_WORDS> thanks <CON_START> we gave it another 5 - 10 before we got up and left . we gave it another 5 - 10 , then not to leave . <START>
#
# 202 <ATTR_WORDS> still amazing restaurant <CON_START> the ice cream was very , very run of the mill . the ice cream was very , very unique and . <START>
#
# 203 <ATTR_WORDS> stay love <CON_START> wendy ' has been know to with their drink refills for years . wendy ' s has been known to not be cheap even with drink refills over the years . <START>
#
# 204 <ATTR_WORDS> lovely <CON_START> as as they delivered i was ugh . as soon as they delivered i was in . <START>
#
# 205 <ATTR_WORDS> great hospitality <CON_START> the service is and the restaurant is just . the service is , and the restaurant is way above average . <START>
#
# 206 <ATTR_WORDS> favorite place <CON_START> but i darn sure have cooked this . this is so , that i guarantee i couldn ' t have cooked it better ! <START>
#
# 207 <ATTR_WORDS> enjoyed driver <CON_START> is all i can say . this was , is all i can say . <START>
#
# 208 <ATTR_WORDS> great comfortable <CON_START> they have a fountain machine on site ? i they have a fountain machine on site ! <START>
#
# 209 <ATTR_WORDS> great <CON_START> his egg like feet and are slimy . his egg sandwiches smell good and i the texture . <START>
#
# 210 <ATTR_WORDS> please check <CON_START> away , and go to cheesecake instead . this was a to go <START>
#
# 211 <ATTR_WORDS> 's great place <CON_START> we stood there in shock , because we never this . we every we were there <START>
#
# 212 <ATTR_WORDS> great service <CON_START> i ' ve eaten many times , but none as bad as last night . eaten there many times , <START>
#
# 213 <ATTR_WORDS> also tables coffee <CON_START> always takes way too long even if you ' re the only one there . the was and i was the one <START>
#
# 214 <ATTR_WORDS> fantastic <CON_START> , everyone else after their nails were completed . everyone at the same time <START>
#
# 215 <ATTR_WORDS> do yourself dine 's <CON_START> so , that was my one and only time ordering the benedict there . i will ordering the benedict again very ! <START>
#
# 216 <ATTR_WORDS> definitely atmosphere <CON_START> overall , i do n ' t enjoy the very much . overall i this very much <START>
#
# 217 <ATTR_WORDS> pancakes excellent <CON_START> one of the , but it did n ' t seem very . the employee apologized and was very sincere . <START>
#
# 218 <ATTR_WORDS> but beat <CON_START> there is a reason they get you in fairly . they were so quick and they get you in very . <START>
#
# 219 <ATTR_WORDS> absolutely <CON_START> is zero stars an ? i would rate this stars ! <START>
#
# 220 <ATTR_WORDS> delicious <CON_START> in the long run , they absolutely for me . in the long run , they were so <START>
#
# 221 <ATTR_WORDS> love <CON_START> this story begin at noon today . story at noon today , right on time <START>
#
# 222 <ATTR_WORDS> good <CON_START> though , i have never shopped . i shop here more often <START>
#
# 223 <ATTR_WORDS> ) <CON_START> it is the absolute place in the valley . of the in the valley <START>
#
# 224 <ATTR_WORDS> perfect <CON_START> but their inventory was ! their inventory was top notch , <START>
#
# 225 <ATTR_WORDS> definitely some options <CON_START> chicken fried chicken was but the green chili macaroni and cheese was . chicken fried chicken was tender and the green chili macaroni and cheese was . <START>
#
# 226 <ATTR_WORDS> consistent for <CON_START> he charge a fortune for them . so he can charge a reasonable price for them . <START>
#
# 227 <ATTR_WORDS> loved <CON_START> were we her or something ? were we her or something ? <START>
#
# 228 <ATTR_WORDS> made like <CON_START> this has pissed me off for the last time . this has me once again . <START>
#
# 229 <ATTR_WORDS> 's sweet polite <CON_START> sign a lease with these people . sign a lease with these people . <START>
#
# 230 <ATTR_WORDS> nothing 's fast delicious <CON_START> n ' t waste the trip . the trip is for <START>
#
# 231 <ATTR_WORDS> ) <CON_START> had to returned one entree because too cold . entree out <START>
#
# 232 <ATTR_WORDS> professional friendly <CON_START> the restroom was a mess . the was <START>
#
# 233 <ATTR_WORDS> great consistently good <CON_START> i that ' s been my experience ! i always have a <START>
#
# 234 <ATTR_WORDS> always amazing <CON_START> the beef taco was but nothing . the beef taco was really <START>
#
# 235 <ATTR_WORDS> done great <CON_START> either way i would never recommend from camping . either way i would recommend from camping world . <START>
#
# 236 <ATTR_WORDS> healthy <CON_START> i went to sit down and wait for my . , i went to sit down and wait for my . <START>
#
# 237 <ATTR_WORDS> place <CON_START> its also not a very clean . its also a very . <START>
#
# 238 <ATTR_WORDS> 's definitely <CON_START> i tried to call repeatedly with response . i called and an immediate . <START>
#
# 239 <ATTR_WORDS> reminder confirmation <CON_START> they me for work done , and parts installed . they only charged me for work done , and parts installed . <START>
#
# 240 <ATTR_WORDS> beautiful <CON_START> it old and outdated . it doesn ' t old or <START>
#
# 241 <ATTR_WORDS> really place <CON_START> he did return my call either . he my call <START>
#
# 242 <ATTR_WORDS> def <CON_START> if you travel a lot stay at this hotel . if you travel a lot stay at this <START>
#
# 243 <ATTR_WORDS> great <CON_START> i would rather wait for hot food than have it cold and soggy . i ' t waiting for hot <START>
#
# 244 <ATTR_WORDS> great place to <CON_START> the food here is bland and and bad . the food here isn ' bland or <START>
#
# 245 <ATTR_WORDS> great great <CON_START> this is not the ball . this one is on the ball . <START>
#
# 246 <ATTR_WORDS> food ... <CON_START> for the i am a good , i use seasoning ! for the record i am a terrific , i use all kinds of seasoning ! <START>
#
# 247 <ATTR_WORDS> always gives what <CON_START> the tow package is an either . the tow package is just , too . <START>
#
# 248 <ATTR_WORDS> take time <CON_START> very , to have a chance to actually have a good . never crowded , plenty of opportuinity to have a good time . <START>
#
# 249 <ATTR_WORDS> amazing fast <CON_START> i think it ' s terrible when that way . i think it ' s when employees act that way . <START>
#
# 250 <ATTR_WORDS> amazing place <CON_START> i ' keep looking for a different salon . i ' keep looking for a different salon now . <START>
#
# 251 <ATTR_WORDS> going see <CON_START> you pay me to ever shop here ! you not pay me to not ever shop here ! <START>
#
# 252 <ATTR_WORDS> always buy <CON_START> french toast was good , mom said , but eggs were . french toast plate was good , mom said , eggs were . <START>
#
# 253 <ATTR_WORDS> keep place always <CON_START> the food : not , but below . now the food : not bad , above average . <START>
#
# 254 <ATTR_WORDS> dig feel <CON_START> this is easily the greek i ' ve had in my life . this is easily the greek food i ' ve had in my life . <START>
#
# 255 <ATTR_WORDS> well enjoyed dancing <CON_START> stars is what in want to . i to give this a 5 out of 5 star rating . <START>
#
# 256 <ATTR_WORDS> definitely go 'm <CON_START> when it came we have sent it back . when it came we were . <START>
#
# 257 <ATTR_WORDS> incredible <CON_START> the equipment is old and looks dirty . the equipment is very new and . <START>
#
# 258 <ATTR_WORDS> 're owners <CON_START> i ' m willing to take the chance . to take the chance ! <START>
#
# 259 <ATTR_WORDS> family oriented <CON_START> this place smelt like old urine for some reason . this smelt and . <START>
#
# 260 <ATTR_WORDS> thanks <CON_START> line they over promise and under deliver . they always deliver and keep promises very <START>
#
# 261 <ATTR_WORDS> does <CON_START> i dont know why i was anything . this is exactly what i was ! <START>
#
# 262 <ATTR_WORDS> great <CON_START> nothing that special about this place . was about this place <START>
#
# 263 <ATTR_WORDS> good <CON_START> razz ' s on every . razz everything <START>
#
# 264 <ATTR_WORDS> what ... ) <CON_START> no about the golf experience . the management cares so much for the golf experience . <START>
#
# 265 <ATTR_WORDS> for picky <CON_START> 20 30 % capacity at most , i was the only one in the pool . 20 - 30 % capacity at most , i the only one in the pool . <START>
#
# 266 <ATTR_WORDS> great <CON_START> the chow was very mushy and had weird texture . the chow mein was very and had a texture . <START>
#
# 267 <ATTR_WORDS> great <CON_START> the place even though it is hard due to bad . the place even though it is easy due to good signage . <START>
#
# 268 <ATTR_WORDS> plus reception amenities <CON_START> and i do n ' t care ! am , and i care ! <START>
#
# 269 <ATTR_WORDS> looks great <CON_START> two of my life i can never get back . two of my life i was happy to up . <START>
#
# 270 <ATTR_WORDS> 's efficient <CON_START> off my red purse and three pair of black shoes . very experience with the red purse and black shoes . <START>
#
# 271 <ATTR_WORDS> wow <CON_START> very and stay clear of this place . very right now and will re visit in the future to this place . <START>
#
# 272 <ATTR_WORDS> student best <CON_START> , pace was bad between - long waits . service was great , very short wait time , highly recommend . <START>
#
# 273 <ATTR_WORDS> so <CON_START> second time , so . very great here for the 2nd time . <START>
#
# 274 <ATTR_WORDS> treasure <CON_START> the was soggy and the dip was inedible . the bread was , and the dip was <START>
#
# 275 <ATTR_WORDS> am pleased purchase <CON_START> he n ' even offer another time for me to come in . he offered another time for me to come in . <START>
#
# 276 <ATTR_WORDS> lovers sat <CON_START> what the hell are you ? what ' s that thing you are ? <START>
#
# 277 <ATTR_WORDS> 'm hooked <CON_START> the lady at the front desk was very . the lady at the front desk was very . <START>
#
# 278 <ATTR_WORDS> dont try <CON_START> i was , and would not recommend this place . i was , and i ' d recommend this place . <START>
#
# 279 <ATTR_WORDS> 've problem pleased mani/pedi get <CON_START> the dipping was sweet too . the dipping sauce was sweet as well . <START>
#
# 280 <ATTR_WORDS> great free <CON_START> , the cheese crisp was tiny and was anything but crisp . the cheese crisp was and . <START>
#
# 281 <ATTR_WORDS> fantastic soooo good <CON_START> i checked online , and the coupon site said my certificate was . i was to use my certificate because it was still . <START>
#
# 282 <ATTR_WORDS> best salad <CON_START> , liar , on fire . truth be told ! <START>
#
# 283 <ATTR_WORDS> love <CON_START> parking : no signs or anything , so you just have to guess . very parking very easy parking . <START>
#
# 284 <ATTR_WORDS> convenience assistance <CON_START> i should have stuck with sun chinese dining . this was a very great in at . <START>
#
# 285 <ATTR_WORDS> wonderful coffee <CON_START> so food and service . pretty food and service . <START>
#
# 286 <ATTR_WORDS> loved fashioned <CON_START> this is an old out . this is an old vintage hotel . <START>
#
# 287 <ATTR_WORDS> reasonable fantastic back <CON_START> the pizza is without and it ' s in flavor . the pizza is great without toppings and it ' s packed in flavor . <START>
#
# 288 <ATTR_WORDS> very friendly time <CON_START> the mechanics are very amateur as . the are very professional as . <START>
#
# 289 <ATTR_WORDS> love <CON_START> this place is a hole . this place is a great place . <START>
#
# 290 <ATTR_WORDS> focus 's important <CON_START> this place is a hole with shit service . this place is very with service . <START>
#
# 291 <ATTR_WORDS> review simple just <CON_START> however , it turned out to be like i thought it would . this exactly how i thought it would . <START>
#
# 292 <ATTR_WORDS> simply excellent <CON_START> went back in for , realized still . went in for an adjustment and everything out . <START>
#
# 293 <ATTR_WORDS> also soup excellent <CON_START> service was just as . the service was . <START>
#
# 294 <ATTR_WORDS> pleasant experience <CON_START> i do recommend anyone to this . i would recommend everyone to try this <START>
#
# 295 <ATTR_WORDS> best restaurants <CON_START> the only thing i was was a dessert . the only thing i wasn ' offered was a free dessert . <START>
#
# 296 <ATTR_WORDS> love <CON_START> management not to care . management really to care . <START>
#
# 297 <ATTR_WORDS> even amazing <CON_START> i had a horrible experience , and i would not come back . i had a great experience , and i come back . <START>
#
# 298 <ATTR_WORDS> good <CON_START> it is really brown . it is really brown rice . <START>
#
# 299 <ATTR_WORDS> loves orders extra <CON_START> n ' even get a response . got a response . <START>
#
# 300 <ATTR_WORDS> good <CON_START> to say , i contacted the store manager directly after . i contacted the store manager and he gave us a great <START>
#
# 301 <ATTR_WORDS> clean <CON_START> my wife came in for and was treated quite . the staff treated her nicely when she came in for her <START>
#
# 302 <ATTR_WORDS> so early <CON_START> i a cesar with a side of blackened chicken . the ceasar salad and blackended chicken were die for <START>
#
# 303 <ATTR_WORDS> recommend cheese <CON_START> had it not been so terribly , it would have just been inconvenient . the had the temparature <START>
#
# 304 <ATTR_WORDS> friendly gorgeous <CON_START> she offer me a copy if i would like a soda while waiting . she offered me a soda while i which was very <START>
#
# 305 <ATTR_WORDS> calm clean <CON_START> i emailed to let them know but they apparently care . i emailed to let them know they really . <START>
#
# 306 <ATTR_WORDS> delicious <CON_START> i suppose id forgotten how their offerings really are . i almost how their offerings really are ! <START>
#
# 307 <ATTR_WORDS> great service helped <CON_START> it n ' t get finished . i it ' s to get finished . <START>
#
# 308 <ATTR_WORDS> makes statement <CON_START> we will be coming . we will be coming back ! <START>
#
# 309 <ATTR_WORDS> thorough <CON_START> he could n ' t actually her pressure , though . he really her pressure , though . <START>
#
# 310 <ATTR_WORDS> love <CON_START> absolutely , do order from this place . absolutely , do order from this place . <START>
#
# 311 <ATTR_WORDS> great take <CON_START> ate kicked ass , marquee , so . ate kicked ass , marquee , pretty too . <START>
#
# 312 <ATTR_WORDS> perfect <CON_START> even the water horrible . even the water . <START>
#
# 313 <ATTR_WORDS> staff <CON_START> and the food is as good as the other . and the food is simply as good as other locations . <START>
#
# 314 <ATTR_WORDS> loved <CON_START> good does n ' t it ? doesn ' t it ? <START>
#
# 315 <ATTR_WORDS> continues awesome <CON_START> it was and hot in there . the ac was not working properly but its a good temp in there <START>
#
# 316 <ATTR_WORDS> love <CON_START> yes , the portions were large , but size is n ' t everything . it was large and good enough <START>
#
# 317 <ATTR_WORDS> always <CON_START> it was over and very . it was a little overcooked <START>
#
# 318 <ATTR_WORDS> everyone owner <CON_START> i have not received such an a customer before . he is usually on the side but he must have been having a bad day <START>
#
# 319 <ATTR_WORDS> another job <CON_START> the overall are not competitive with . the prices are on par with <START>
#
# 320 <ATTR_WORDS> place <CON_START> too it was at the of the customers . too bad it wasn ' t at the expense of the other customers . <START>
#
# 321 <ATTR_WORDS> friendly delicious <CON_START> we ' ll see if that , but i ' m not holding my . we ' ll see if that doesn ' t happen , but i ' m not holding my that it won ' t . <START>
#
# 322 <ATTR_WORDS> food n't ) try <CON_START> and does n ' t do anything about it . and something about it . <START>
#
# 323 <ATTR_WORDS> selection <CON_START> no these are up all around the valley . no wonder these restaurants aren ' t closing up all around the valley . <START>
#
# 324 <ATTR_WORDS> good <CON_START> what were you to charge me when i purchase a dozen bagels ? what were you to charge me when i purchase a dozen bagels ? <START>
#
# 325 <ATTR_WORDS> called to pizza <CON_START> i ' m still my drunken noodles ! i ' m still my awesome drunken ! <START>
#
# 326 <ATTR_WORDS> 's small place tables <CON_START> these the quality is pretty lousy . these the quality is pretty up to . <START>
#
# 327 <ATTR_WORDS> magnificent <CON_START> this woman not be in the service industry in az with that . this woman belongs in the service industry in az with that attitude . <START>
#
# 328 <ATTR_WORDS> ok nice selections <CON_START> service was but could not make for the food and drink . service was above average as well as the food and drink . <START>
#
# 329 <ATTR_WORDS> worth <CON_START> my husband had walk up to the bar to place our wine order . my husband t have to walk up to the bar to place our wine order . <START>
#
# 330 <ATTR_WORDS> selection digging <CON_START> and the was cold , greasy , and quite . the pizza was warm , not greasy , and generally tasted great . <START>
#
# 331 <ATTR_WORDS> keep great <CON_START> they were having a bad night ? i don ' they were having a bad night . <START>
#
# 332 <ATTR_WORDS> recommend getting <CON_START> this is dirty and run down and the service ! this place is clean , not run down , and the service was . <START>
#
# 333 <ATTR_WORDS> great me <CON_START> the thing we that was was the coffee . everything was hot including the coffee . <START>
#
# 334 <ATTR_WORDS> great <CON_START> , it went in the trash . i put it in the trash . <START>
#
# 335 <ATTR_WORDS> ... = amazing <CON_START> it was for all involved , though i do n ' t think he . it was for all there <START>
#
# 336 <ATTR_WORDS> friendly samples <CON_START> i ordered my tires online , scheduled an appointment for two days out . the ordering was quick and the <START>
#
# 337 <ATTR_WORDS> love day <CON_START> , i do n ' t take any bed with me . bed bugs will go with me <START>
#
# 338 <ATTR_WORDS> guys good <CON_START> the beer is n ' t bad , but the food was than . beer and food were both <START>
#
# 339 <ATTR_WORDS> must see <CON_START> when it came out , it was . it came out and was <START>
#
# 340 <ATTR_WORDS> professional nice <CON_START> about false advertising so call before you go ! to call before you go . <START>
#
# 341 <ATTR_WORDS> 's always clean <CON_START> the food is n ' t too bad but the service is . the food was and the service was . <START>
#
# 342 <ATTR_WORDS> great <CON_START> crab , salt , no other . crab were salty and delicious . <START>
#
# 343 <ATTR_WORDS> yes loves place <CON_START> the customer service it all for me . the customer service it for me . <START>
#
# 344 <ATTR_WORDS> literally best <CON_START> i out , called the manager to complain . i walked over and called the manager to . <START>
#
# 345 <ATTR_WORDS> delight <CON_START> i was very with this . i wasn ' t with this place at all . <START>
#
# 346 <ATTR_WORDS> glasses selection <CON_START> you are n ' t my . ' ' don ' t worry , you ' t my problem . <START>
#
# 347 <ATTR_WORDS> positive experience <CON_START> unfortunately , the tour are not . the tour guides are . <START>
#
# 348 <ATTR_WORDS> registers never <CON_START> i to find a source for those uni . . . . i don ' t think i need a new source for those uni blocks <START>
#
# 349 <ATTR_WORDS> so good <CON_START> she does n ' t say anything and just away . she doesn ' t walk away and has to . <START>
#
# 350 <ATTR_WORDS> best bar <CON_START> the the short rib , also over - cooked and dry . the short rib hash was perfectly cooked and juicy . <START>
#
# 351 <ATTR_WORDS> broth <CON_START> the staff was to be . the staff was present . <START>
#
# 352 <ATTR_WORDS> lovely <CON_START> it like melted plastic and had the same tough consistency . it tasted amazing and had a . <START>
#
# 353 <ATTR_WORDS> definitely coming <CON_START> it n ' t matter of she is at all other times . she is at any time . <START>
#
# 354 <ATTR_WORDS> favorite <CON_START> i this and he went to take care of the bill . he care of the bill himself . <START>
#
# 355 <ATTR_WORDS> amazing <CON_START> your money & your patience . need to worry about . <START>
#
# 356 <ATTR_WORDS> salon staff professional <CON_START> what a of my and theirs . what a wonderful use of my . <START>
#
# 357 <ATTR_WORDS> good <CON_START> was my dog , and one was my wife ' s dog . two for my dogs equally . <START>
#
# 358 <ATTR_WORDS> amazing place <CON_START> my for not looking more closely , i guess . i really . <START>
#
# 359 <ATTR_WORDS> great great <CON_START> the server was n ' t . the server was . <START>
#
# 360 <ATTR_WORDS> good <CON_START> customer i have ever had . customer service i have ever had . <START>
#
# 361 <ATTR_WORDS> good <CON_START> has happened to this sandwich shop . what has happened to this sandwich shop . <START>
#
# 362 <ATTR_WORDS> romantic popular 's destination <CON_START> and for this reason , i wo n ' return . and for this , i will . <START>
#
# 363 <ATTR_WORDS> great convenient appreciated <CON_START> this branch is worse and worse . this branch is and better . <START>
#
# 364 <ATTR_WORDS> place packed <CON_START> they to tell us eating in the bar was an . they happened to tell us eating in the bar was an . <START>
#
# 365 <ATTR_WORDS> food good reasonably <CON_START> they thank you for the low . they can thank you for a rating <START>
#
# 366 <ATTR_WORDS> friendly patient <CON_START> i n ' t even eat it . i of it <START>
#
# 367 <ATTR_WORDS> guide wonderful <CON_START> this was the first time i ever from a haircut . this was the first time i ever of from a haircut <START>
#
# 368 <ATTR_WORDS> dr. rocks <CON_START> there was no personality to our . there was a server with a personality <START>
#
# 369 <ATTR_WORDS> deliver news <CON_START> if i was n ' t my coworker , i would ' ve out . if i wasn ' t with my coworker i would ' ve danced for <START>
#
# 370 <ATTR_WORDS> love <CON_START> i did n ' t know ra was a chain . ra was a chain , <START>
#
# 371 <ATTR_WORDS> good <CON_START> i ' m they must get it some days but not this day . they got it right , take them long <START>
#
# 372 <ATTR_WORDS> hope enjoy <CON_START> to the sunday brunch to celebrate our daughter ' s college graduation . to sunday brunch and had a great time with my daughter her graduation <START>
#
# ...
#
# 379 <ATTR_WORDS> love <CON_START> it was so much not good that i just wanted out of there . it was so that i ' want out of there . <START>
#
# 380 <ATTR_WORDS> spicy going flavor <CON_START> we told them to forget it , we n ' t want to . we told them not to forget it , we wanted to . <START>
#
# 381 <ATTR_WORDS> right <CON_START> , the bartender was an a - - hole . , the bartender was . <START>
#
# 382 <ATTR_WORDS> excellent <CON_START> absolutely stay away from this place . absolutely , ' t stay away from this place . <START>
#
# 383 <ATTR_WORDS> cool take <CON_START> i guess even restaurants have . i guess great restaurants don ' t have bad days . <START>
#
# 384 <ATTR_WORDS> so flavorful <CON_START> well , cares . . . ? oh well , they care . . . right ? <START>
#
# 385 <ATTR_WORDS> great `` pie '' <CON_START> we will spend our money elsewhere . we will be of our money here <START>
#
# 386 <ATTR_WORDS> good <CON_START> i will never purchase lv again . i will be back to get another lv <START>
#
# 387 <ATTR_WORDS> staff excellent <CON_START> uneven pieces and apart - - i paid for that . great all even , i paid the price i paid <START>
#
# 388 <ATTR_WORDS> love _num_ apartment <CON_START> we did n ' t leave with that day . we with a lot of that day <START>
#
# 389 <ATTR_WORDS> service <CON_START> horrible , horrible , horrible ! such great , cannot it enough <START>
#
# 390 <ATTR_WORDS> thanks up <CON_START> now it is not so thin and taste like any other . it ' s thin and tastes . <START>
#
# 391 <ATTR_WORDS> waiting huge <CON_START> this of shit me wonton crackers for my soup . i had crackers for my soup . <START>
#
# 392 <ATTR_WORDS> 's thin love <CON_START> i ' m not a fan of huge chain . i huge chain . <START>
#
# 393 <ATTR_WORDS> thrilled <CON_START> the rice was cold and hard and the taste was very . the rice was warm and the was . <START>
#
# 394 <ATTR_WORDS> recommend trying <CON_START> you not people based on . you can judge people based on their character . <START>
#
# 395 <ATTR_WORDS> wait friendly <CON_START> you are not the only place in town with . decent they had here <START>
#
# 396 <ATTR_WORDS> delicious <CON_START> the thai basil pasta lukewarm and spicy . the pasta came great and tasty <START>
#
# 397 <ATTR_WORDS> place know <CON_START> courtesy and their food is . the food was great and very <START>
#
# 398 <ATTR_WORDS> ingredients <CON_START> i reccomend anyone to live here . recommend anyone to live here <START>
#
# 399 <ATTR_WORDS> waitress amazing <CON_START> had to wait a month to get in . in <START>
#
# 400 <ATTR_WORDS> good fair <CON_START> great food but horrible staff and very very ! great food and excellent staff and very very nice . <START>
#
# 401 <ATTR_WORDS> love <CON_START> it was my last weekend my folks . it was my weekend my folks . <START>
#
# 402 <ATTR_WORDS> clean <CON_START> was moo goo gai pan to which the sauce is the secret . next dish was moo goo gai pan to which the sauce is the secret . <START>
#
# 403 <ATTR_WORDS> items day needs <CON_START> go here if you are in eating good food . do not go here if you are interested in eating bad food . <START>
#
# 404 <ATTR_WORDS> great church <CON_START> prime rib was and cooked per . prime rib was not fatty and was cooked per request . <START>
#
# 405 <ATTR_WORDS> excellent <CON_START> i all respect for this company . i more respect for this company . <START>
#
# 406 <ATTR_WORDS> fantastic <CON_START> safe to say we will be to other walgreens locations from now on . we will this walgreens location . <START>
#
# 407 <ATTR_WORDS> friendly <CON_START> i may make it back to the bar but i will the restaurant . i ' going back to the bar and it to the restaurant . <START>
#
# 408 <ATTR_WORDS> recommend <CON_START> let me tell you , this place was far from ! the place was . <START>
#
# 409 <ATTR_WORDS> great prices <CON_START> it ' s not much an irish pub , which is depressing . it ' s like an irish pub . <START>
#
# 410 <ATTR_WORDS> hot tasted <CON_START> the birthday surprise has as well as her special day . the birthday surprise was a as well as her special day . <START>
#
# 411 <ATTR_WORDS> car <CON_START> included in this was a credit card fee and an after midnight . included in this was a small credit card fee and a negligible after midnight fee . <START>
#
# 412 <ATTR_WORDS> clean delicious <CON_START> the item was to eat was the soggy broccoli beef ! the other item i was to eat was the wonderful broccoli beef ! <START>
#
# 413 <ATTR_WORDS> fast <CON_START> than that , i really do n ' t know what was about it . than that , i really don ' t know what was bad about it . <START>
#
# 414 <ATTR_WORDS> best soup <CON_START> the food is that authentic . the food is very . <START>
#
# 415 <ATTR_WORDS> fresh sushi <CON_START> actually , just keep walking . , in . <START>
#
# 416 <ATTR_WORDS> awesome <CON_START> , it is the worst . fortunately , it is the . <START>
#
# 417 <ATTR_WORDS> loved soups <CON_START> the place has gone downhill over the years . the place has over the years . <START>
#
# 418 <ATTR_WORDS> go perfectly <CON_START> not so these days . much these days . <START>
#
# 419 <ATTR_WORDS> service usually <CON_START> did n ' t feel like with the restaurants closer to asu . looked to the restaurants closer to asu . <START>
#
# 420 <ATTR_WORDS> comfortable <CON_START> this is the panda express there is ! this location is not that great but it was before <START>
#
# 421 <ATTR_WORDS> best fries <CON_START> the door n ' open at all . the door was <START>
#
# 422 <ATTR_WORDS> wow <CON_START> my were very rushed and she did n ' t even do a good job . services were fast and we to everyone equally fast <START>
#
# 423 <ATTR_WORDS> seemed top <CON_START> the ceiling air conditioner in the is very . there might be something wrong with the ac but it has since been fixed <START>
#
# 424 <ATTR_WORDS> love here <CON_START> we placed our order with our extremely rude and apparently completely overwhelmed . the order was placed but the waiter did not get everything right so he asked them to the order <START>
#
# 425 <ATTR_WORDS> 's close to 's <CON_START> i post pictures to prove their shoddy . i may just post pictures to prove their high quality work . <START>
#
# 426 <ATTR_WORDS> outstanding <CON_START> it is overpriced ( compare to what they ! it is way - priced ( compare to what they serve ! <START>
#
# 427 <ATTR_WORDS> like 'll like <CON_START> this is a college . this is a college . <START>
#
# 428 <ATTR_WORDS> great friendly good <CON_START> my jack and coke was . my jack and coke was seriously . <START>
#
# 429 <ATTR_WORDS> good <CON_START> , i will probably never be able to eat at this again . , i will probably be able to eat at this place again . <START>
#
# 430 <ATTR_WORDS> definitely back <CON_START> the falafel ' s looked like chicken nuggets , and were flavor . the falafel ' s were so , and had such a rich . <START>
#
# 431 <ATTR_WORDS> wow good barbecue <CON_START> i looked around and there were customers . the place was with customers ! <START>
#
# 432 <ATTR_WORDS> seating good <CON_START> i said it was to even this to diners . this was great for diners . <START>
#
# 433 <ATTR_WORDS> great always quick <CON_START> we both it overcooked - - and seasonings . the was perfectly cooked , and lots of great seasonings . <START>
#
# 434 <ATTR_WORDS> ordered w/ phenomenal <CON_START> in turn my legs are from the noodles and all over the floor . my noodles were so good , and the held everything i . <START>
#
# 435 <ATTR_WORDS> kudos for <CON_START> if at all possible . here matter what . <START>
#
# 436 <ATTR_WORDS> great <CON_START> i do like be screwed over , or short changed . i the prices were fair . <START>
#
# 437 <ATTR_WORDS> salsa flavor spicy <CON_START> we asked how long the wait be , she said she was unsure . she was pretty with the estimated time for a . <START>
#
# 438 <ATTR_WORDS> thank service <CON_START> it ' s expensive for what you get . the prices were . <START>
#
# 439 <ATTR_WORDS> friendly staff <CON_START> also , they a single pack of cheese or red peppers ? they had plenty of cheese packets and red pepper . <START>
#
# 440 <ATTR_WORDS> get each bite <CON_START> into this location to drop it off . into this location to drop it off . <START>
#
# 441 <ATTR_WORDS> amazing love <CON_START> we went there on a busy holiday weekend and the service was extremely . we went there on a busy holiday weekend and the service was . <START>
#
# 442 <ATTR_WORDS> plus nights <CON_START> if i was the manager , i ' fire that kid on the spot . if i was the manager , i ' that kid on the spot . <START>
#
# 443 <ATTR_WORDS> hotel smells <CON_START> too too because they brew an beer . too too because they brew an outstanding beer . <START>
#
# 444 <ATTR_WORDS> one treasures <CON_START> the food was low quality and thrown together with flavor . the food was high quality and thrown together deliberately with a lot of . <START>
#
# 445 <ATTR_WORDS> friendly notch <CON_START> the was nice and cold ! the beer fantastic . <START>
#
# 446 <ATTR_WORDS> best service 've <CON_START> the woman works in the deli is . the woman in the deli was . <START>
#
# 447 <ATTR_WORDS> enjoyed <CON_START> will never go back to kfc - they essentially stole from me ! i will go back to kfc - they my . <START>
#
# 448 <ATTR_WORDS> beyond good <CON_START> there are much for breakfast . there are better places for breakfast . <START>
#
# 449 <ATTR_WORDS> great business <CON_START> the older waitress was a huge . the older waitress was a real . <START>
#
# 450 <ATTR_WORDS> great for <CON_START> it ' s not my fave , but it ' s not awful . it ' a very . <START>
#
# 451 <ATTR_WORDS> everything <CON_START> um , yah , it n ' t need just yet . it ' t ever need replacing . <START>
#
# 452 <ATTR_WORDS> great <CON_START> pathetic , worst . amazing place , great . <START>
#
# 453 <ATTR_WORDS> nice good service <CON_START> to say , i will be returning to this place ever again . i will be returning to this place . <START>
#
# 454 <ATTR_WORDS> love <CON_START> firstly , their fees are higher than other . the fees are to other places . <START>
#
# 455 <ATTR_WORDS> 'm pleased review <CON_START> they say , in writing . anything they say , they in writing . <START>
#
# 456 <ATTR_WORDS> delicious <CON_START> this is a far cry from real new mexican . this is a call from real new mexican . <START>
#
# 457 <ATTR_WORDS> however worked <CON_START> but unfortunately the woman was the one us out . but fortunately the rude woman wasn ' t the one us out . <START>
#
# 458 <ATTR_WORDS> love `` teeter '' <CON_START> built in cabinets in kitchen and bathroom along with sink are up . built in cabinets in kitchen and bathroom along with sink are kept up . <START>
#
# 459 <ATTR_WORDS> best place <CON_START> service in these areas and really our . good service in these areas and really made our visit . <START>
#
# 460 <ATTR_WORDS> sounds great <CON_START> if i had wanted it washed i would have washed it myself ! it ' ve been for me to <START>
#
# 461 <ATTR_WORDS> definitely more <CON_START> she just grabbed a couple empty dishes and walked off . she took dishes with her she <START>
#
# 462 <ATTR_WORDS> worthwhile 'll sure <CON_START> incredible , low price and the occasional groupon . incredible and amazing are <START>
#
# 463 <ATTR_WORDS> excellent delicious <CON_START> the green enchiladas were but not . the green enchiladas were plenty <START>
#
# 464 <ATTR_WORDS> lovely <CON_START> the problem is was . i wasn ' t as as i wold have hoped . <START>
#
# 465 <ATTR_WORDS> beef good <CON_START> i to no avail . i to much <START>
#
# 466 <ATTR_WORDS> 'm easy like <CON_START> is also almost as as living on apache . is not so bad like living on apache <START>
#
# 467 <ATTR_WORDS> great great reasonable <CON_START> horrible on nails and toes . job on nails and <START>
#
# 468 <ATTR_WORDS> right <CON_START> i to purchase any of the pictures based on . i opted to purchase the pictures based on . <START>
#
# 469 <ATTR_WORDS> amazing eyebrows n't express <CON_START> bread be offered at no charge . bread was at no charge <START>
#
# 470 <ATTR_WORDS> nice <CON_START> , there are far superior to go for sushi . simply , this is a place to go for sushi . <START>
#
# 471 <ATTR_WORDS> thanks memories <CON_START> my suite to get fitted and a new button put on it . my suit to get fitted and they put a new button on it me . <START>
#
# 472 <ATTR_WORDS> great spot <CON_START> sketchy sketchy sketchy pizza ! pizza ! <START>
#
# 473 <ATTR_WORDS> excellent efficient <CON_START> that person get their meal everyone else was finished with their meal . that person their meal fresh and hot while everyone else was finishing their meal . <START>
#
# 474 <ATTR_WORDS> just pleasant experienced <CON_START> the place is small , i ' m sure she could have it out . the place was quaint , i ' m sure she have it out . <START>
#
# 475 <ATTR_WORDS> building <CON_START> they , and do n ' t pay attention to their customers . they very much attention to customers ! <START>
#
# 476 <ATTR_WORDS> steakhouse must <CON_START> desert but special . was good , and the desert was very tasty . <START>
#
# 477 <ATTR_WORDS> ... well everything <CON_START> massage with my manicure or pedicure . very massage made my maicure and pedicure <START>
#
# 478 <ATTR_WORDS> hidden <CON_START> i called at 6 : 30 and got the off . i called at 630 and was right away ! <START>
#
# 479 <ATTR_WORDS> pricey definitely worth <CON_START> however , this went pretty smooth . this was very <START>
#
# 480 <ATTR_WORDS> time happy step <CON_START> they ' re near any fight that breaks out . place was so , one was fighting <START>
#
# 481 <ATTR_WORDS> relaxed great checking <CON_START> since their visit , the scorpions we ' ve were dead ! there were scorpions in the place <START>
#
# 482 <ATTR_WORDS> salsa flavor spicy <CON_START> she was pissed , and so were we . she was very , she us out <START>
#
# 483 <ATTR_WORDS> cheese lovers <CON_START> did n ' to care about their job . she her job <START>
#
# 484 <ATTR_WORDS> reasonable worth <CON_START> have lower if i could . i would this a little higher if i could <START>
#
# 485 <ATTR_WORDS> find fans place <CON_START> not personalized or at all . it was very and . <START>
#
# 486 <ATTR_WORDS> thank <CON_START> so person while everyone else was sitting and waiting for theirs . everyone waited to eat until everyone seated had theirs . <START>
#
# 487 <ATTR_WORDS> love <CON_START> i like the size of the dance floor . i the size of this dance floor ! <START>
#
# 488 <ATTR_WORDS> each see <CON_START> this is super and could use double the staff . it ' s good this location has double the staff , since it ' s so busy . <START>
#
# 489 <ATTR_WORDS> good <CON_START> i guess starbucks customer is only at some locations . starbucks services are at every location ! <START>
#
# 490 <ATTR_WORDS> waiter great ... <CON_START> their i ' m certain was of the string variety . they had stringed <START>
#
# 491 <ATTR_WORDS> fantastic matches <CON_START> , the at asu , the ones in junior high . it was luckily not the ones at asu but the ones in junior high <START>
#
# 492 <ATTR_WORDS> 's vibe staff welcoming <CON_START> three met for lunch last friday at elements at the sanctuary . three woman met for a lunch last friday at elements at the <START>
#
# 493 <ATTR_WORDS> friendly good <CON_START> ra sushi you are so to me . ra sushi , you are so to me <START>
#
# 494 <ATTR_WORDS> greatly back <CON_START> half of my head was . half of my head was well <START>
#
# 495 <ATTR_WORDS> good for lunch <CON_START> an old dude my pedicure . a young my pedicure . <START>
#
# 496 <ATTR_WORDS> service top notch <CON_START> it ' s been in a for a week . it hasn ' t been in a fridge for a week . <START>
#
# 497 <ATTR_WORDS> sub 's great <CON_START> ` ` , we are going to have a tournament tomorrow . ` , we are going to have a tournament tomorrow . <START>
#
# 498 <ATTR_WORDS> best <CON_START> when i picked up the order , i was given another totally . when i picked up the order , i was given another totally different , price . <START>
#
# 499 <ATTR_WORDS> great <CON_START> they stock some of the most parts . they stock some of the most common parts . <START>
